# %% [markdown]
# # Lab 4 - DeepONets
# DeepONets are neural network architectures designed to learn operators (i.e., mappings between functions). Consider the one dimensional boundary value problem
# $$
# \begin{aligned}
# \nabla\cdot\left(a\nabla u^a\right) &= f \quad \text{in } (0,1)=:\Omega\\
# u(0) = u(1) &= 0.
# \end{aligned}
# $$
# For some value $a_{\min{}}$, we define the admissible data set
# $$
# \mathcal{A} = \left\{a\in L^\infty(\Omega) : a(x)\geq a_{\min{}}\text{ almost everywhere}\right\}
# $$
# and the solution operator
# $$
# \mathcal{S}:
# \begin{cases} \mathcal{A} \to H^1_0(\Omega)\\
# a\mapsto u^a.
# \end{cases}
# $$
# We want to approximate the operator $\mathcal{S}$ over some set $\mathcal{D}\subset\mathcal{A}$ with a deepONet $\mathcal{G}$.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from DNN import DeepNet
from utilities import plot_data, plot_results, LprelLoss

torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.set_default_dtype(torch.float64)

# %% [markdown]
# # Data Loading
# We fix $f=1$ and consider the data set
# $$
# \mathcal{D} = \left\{ a(x) = 1+\sum_{i=1}^3 y_i \mathbb{1}_{((i-1)/3, i/3)}(x): y_i\in (0,8)\right\}
# $$
# And solve the problem with linear finite elements. The code to solve the problem is given in the files `FEsolver.py` and `data_gen.ipynb`, though these require installing `FEniCSx`. To use the data, you can also load it from the respective files, that contain
# - coordinates $x_1, \dots, x_M$
# - coefficient values $a(x_1), \dots, a(x_M)$
# - solution values $u(x_1), \dots, u(x_M)$
# - solution gradient $u'(x_1), \dots, u'(x_M)$.

# %%
x = torch.load("data/x_train.pt")
coefs = torch.load("data/a_train.pt")
solutions = torch.load("data/u_train.pt")
grad_solutions = torch.load("data/gradu_train.pt")

# check the dimension of the data
print("Dimension of x: ", x.shape)
print("Dimension of coefs: ", coefs.shape)
print("Dimension of solutions: ", solutions.shape)
print("Dimension of gradients of solutions: ", grad_solutions.shape)
# Out:
# Dimension of x:  torch.Size([64])
# Dimension of coefs:  torch.Size([250, 64])
# Dimension of solutions:  torch.Size([250, 64])
# Dimension of gradients of solutions:  torch.Size([250, 64])

# %% [markdown]
# # Plot some input-output pairs
# Use the function `plot_data` provided in `utilities.py` to plot some $(a, \mathcal{S}(a))$ pairs.

# %%
plot_data(x, {'Coefficient': coefs, 'Solution': solutions}, num_samples_to_plot=3)

# %%
plot_data(x, {'Solution': solutions, 'Gradient': grad_solutions}, num_samples_to_plot=3)

# %% [markdown]
# # DeepONet architecture
# We now define the `DeepONet` class. We will use the `DeepNet` class that we have used in the previous labs.
# A deep operator network is composed of
# - a neural network $\Phi_{\mathrm{app}} : \mathbb{R}^M\to \mathbb{R}^N$ (branch network)
# - a neural network $\Phi_{\mathrm{dec}} : \mathbb{R}^d \to \mathbb{R}^N$ (trunk network)
#
# The `forward` function will take as input a point $x\in\mathbb{R^d}$ and a vector $a_1, \dots a_M \in \mathbb{R}^M$ and return
# $$
# \mathcal{G}(\mathcal{E}(a))(x) = \Phi_{\mathrm{app}}(a_1, \dots, a_M) \cdot \Phi_{\mathrm{dec}}(x)
# $$
# An implementation detail: we want to be able to evaluate on multiple points at once: the function above should be implemented so that if instead of a single point $x$ we have $\mathbf{x} = [x_1, \dots, x_p]^\top$, the function above should return
# $$
# \Big(\Phi_{\mathrm{app}}(a_1, \dots, a_M) \cdot \Phi_{\mathrm{dec}}(x_i)\Big)_{i=1}^p.
# $$
# The function takes as input the activation functions, the dimensions $M$, $d$, the widths of the layers, the dimension $N$, and a flag `bc`. If the flag is set to `True` the forward function above is replaced by
# $$
# \Phi_{\mathrm{app}}(a_1, \dots, a_M) \cdot \big(x(1-x)\Phi_{\mathrm{dec}}(x)\big)
# $$
# so that the boundary conditions are automatically satisfied.
#
# We will also define a class method `grad_forward` that computes the derivative
# $$
# \Big(\nabla_x \mathcal{G}(\mathcal{E}(a))\Big)(x) = \Phi_{\mathrm{app}}(a_1, \dots, a_M) \cdot \Big(\nabla_x\Phi_{\mathrm{dec}}\Big)(x)
# $$
# Note that this function is not used for the training, but only to inspect the results. You can postpone its implementation (and comment the corresponding part of the code in the next sections).

# %%
# Device configuration
device = torch.device("cpu")
torch.set_default_device(device)

class DeepONet(nn.Module):
    def __init__(self, activation_branch, activation_trunk, branch_input_dim:int, trunk_input_dim:int, 
                 branch_hidden_dims:list, trunk_hidden_dims:list, num_basis:int, bc:bool=False):
        """
        DeepONet class. This class defines the architecture of the DeepONet.
        The DeepONet is composed of two subnetworks: the branch network and the trunk network.
        
        Args:
        activation: activation function
        branch_input_dim: input dimension of the branch network
        trunk_input_dim: input dimension of the trunk network
        branch_hidden_dims: list of the hidden dimensions of the branch network
        trunck_hidden_dims: list of the hidden dimensions of the trunk network
        num_basis: number of basis functions
        bc: boolean, if True, we multiply the output of the trunk network by x*(1-x) to satisfy the boundary condition
        """
        super(DeepONet, self).__init__()

        # The output dimension of the trunk network must be equal to the number of basis functions.
        assert trunk_hidden_dims[-1] == num_basis 

        self.activation_branch = activation_branch # initialize the branch activation function
        self.activation_trunk = activation_trunk # initialize the trunk activation function
        self.bc = bc # store the bc flag
        self.branch_net = DeepNet(activation_branch, branch_input_dim, branch_hidden_dims) # create the approximation network
        self.trunk_net = DeepNet(activation_trunk, trunk_input_dim, trunk_hidden_dims)  # create the decoding network

    def forward(self, branch_in, x):
        # compute the output of the approximation and decoding NNs
        # print("evaluating branch output ------------------------------------------------------ ")
        # print("branch_in shape: ", branch_in.shape)
        # print(self.branch_net)
        branch_output = self.branch_net.forward(torch.transpose(branch_in, 0, 1)) # output of the branch network  
        # print("done1---------------------------------------------------- ")
        # print(self.trunk_net)
        print(x.unsqueeze(-1).shape)
        trunk_output = self.trunk_net.forward(torch.transpose(x.unsqueeze(-1), 0, 1)) # output of the trunk network
        # print("done2------------------------------------------------------ ")
        


        if self.bc:
            # print("applying bc ------------------------------------------------------ ")
            trunk_output = trunk_output * x * (1 - x)  # update for new formula
            return torch.sum(branch_output * trunk_output, dim=1, keepdim=True)
        else:
            # print("no bc ------------------------------------------------------ ")
            # print(branch_output.shape, trunk_output.shape)
            # print(torch.sum(branch_output * trunk_output, dim=1, keepdim=True))
            # print("okay ------------------------------------------------------ ")
            return torch.transpose(torch.sum(branch_output * trunk_output, dim=1, keepdim=True), 0, 1)

    def grad_forward(self, branch_in, x):
        # compute the gradient of the ONet at the points x
        x.requires_grad_(True)
        branch_output = self.branch_net.forward(torch.transpose(branch_in, 0, 1))
        trunk_output = self.trunk_net.forward(torch.transpose(x,0,1))

        grad_trunk = torch.zeros_like(trunk_output)

        for i in range(trunk_output.shape[1]):
            grad_trunk[:, i] =  torch.autograd.grad(self.trunk_net(x)[i], x, create_graph = True)[0] # gradient of trunk_output[:, i] at the points x
        if self.bc:
            grad_trunk = grad_trunk #??? update for new formula
            return None #...
        else:
            return branch_output * grad_trunk

# %% [markdown]
# We now define a DeepONet with proper input dimensions, an activation function (choose one and play with different activation functions), where both trunk and branch nets have a total of `3` layers with hidden dimension `50` and `output_dim = num_basis = 80`.

# %%
d = int(x.shape[0])
M = int(coefs.shape[0])

# %%
# Initialize the model # activation_branch, activation_trunk, branch_input_dim:int, trunk_input_dim:int, 
                 # branch_hidden_dims:list, trunk_hidden_dims:list, num_basis:int,
FNN = DeepNet(torch.nn.Tanh(), 1, [5,5,5], 1)  #ok
model = DeepONet(torch.nn.Tanh(), torch.nn.Tanh(), M, d, [50,80], [50,80], 80).to(device)

model
# Out:
# DeepONet(
#   (activation_branch): Tanh()
#   (activation_trunk): Tanh()
#   (branch_net): DeepNet(
#     (activation): Tanh()
#     (hidden): ModuleList(
#       (0): Linear(in_features=250, out_features=50, bias=True)
#       (1): Linear(in_features=50, out_features=80, bias=True)
#     )
#   )
#   (trunk_net): DeepNet(
#     (activation): Tanh()
#     (hidden): ModuleList(
#       (0): Linear(in_features=64, out_features=50, bias=True)
#       (1): Linear(in_features=50, out_features=80, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Training
# We choose the number of epochs and the meta parameters of the training algorithm. We use adam with `MSELoss` to compute the distance between the exact and predicted values.

# %%
# train the model
num_epochs = int(5000)
learning_rate = 5e-4
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1250, gamma=0.5)

# Choose a criterion
criterion = nn.MSELoss()
# criterion = LprelLoss(2, True)

# %% [markdown]
# We introduce the funciton that performs the training.

# %%
def train_deeponet(model, x, rhs, solutions, num_epochs, loss_values):
    model.train()
    for epoch in range(num_epochs):

        optimizer.zero_grad() # Zero the gradients
        # print(rhs)
        output = model(rhs.to(device), x.to(device)) # Forward pass
        # print("hi?? ------------------------------------------------------ ")
        # print("output", output.shape)
        # print('solutions', solutions.to(device).shape)
        loss = criterion(output, solutions.to(device))
        # print("hello! ------------------------------------------------------ ")
        loss.backward() # Backward pass
        optimizer.step() # Update the weights
        loss_values.append(loss.cpu().detach().numpy()) # Store the loss

        if (epoch + 1) % 100 == 0:
            print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4e}')

    return loss_values

# %% [markdown]
# ## Training the deepONet
#
# The following block of code trains the model for a number of epochs equals to `num_epochs`. Note that if you rerun this block the training of the model **continues** for other `num_epochs` epochs.

# %%
try:
    print(f"We have already trained the model for {len(loss_values)} epochs.")
except:
    loss_values = []
    
loss_values = train_deeponet(model, x, coefs, solutions, num_epochs, loss_values)
# Out:
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# C:\Users\elena\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\utils\_device.py:103: UserWarning: Using a target size (torch.Size([250, 64])) that is different to the input size (torch.Size([1, 64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return func(*args, **kwargs)
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [100/5000], Loss: 5.6998e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [200/5000], Loss: 4.5225e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [300/5000], Loss: 4.1964e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [400/5000], Loss: 4.1393e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [500/5000], Loss: 4.1341e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [600/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [700/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [800/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [900/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1000/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1100/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1200/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1300/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1400/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1500/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1600/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1700/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1800/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [1900/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [2000/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [2100/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [2200/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [2300/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# ...
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [4300/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [4400/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [4500/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [4600/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [4700/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [4800/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [4900/5000], Loss: 4.1338e-02
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# torch.Size([64, 1])
# Epoch [5000/5000], Loss: 4.1338e-02

# %% [markdown]
# Plot the loss function during the training

# %%
plt.semilogy(range(len(loss_values)), loss_values)
plt.grid()

# %% [markdown]
# # (Qualitative) evaluation of the trained deepONet
#
# The following function computes the predicted values on some coefficients and the corresponding loss.

# %%
def evaluate_deeponet(model, x, coefs, solutions):
    model.eval()
    with torch.no_grad():
        u_pred = model(coefs.to(device), x.to(device))
        loss = criterion(u_pred, solutions.to(device))
        print(f'Loss: {loss.item():.4e}')
    return u_pred

# %% [markdown]
# We then plot the comparison on three random functions from the training set. Launching the code again will show (potentially) new functions.

# %%
import random
for (idplot, i) in enumerate(random.sample(range(solutions.shape[0]), 3)):
    print(idplot,i)
# Out:
# 0 172
# 1 247
# 2 110

# %%
# Plot results
predicted_solutions = evaluate_deeponet(model, x, coefs, solutions)
print(solutions.shape)
plot_results(x.detach(), solutions, predicted_solutions.detach(), num_samples_to_plot=3)
# Out:
# torch.Size([64, 1])
# Loss: 4.1338e-02
# torch.Size([250, 64])
# initial shapes
# torch.Size([250, 64])
# torch.Size([1, 64])

# %% [markdown]
# We now do the same thing with the gradients, still comparing with functions in the training set.

# %%
predicted_grads = model.grad_forward(coefs, x) #????
plot_results(x.detach(), grad_solutions, predicted_grads.detach(), num_samples_to_plot=3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 predicted_grads = model.grad_forward(coefs, x.unsqueeze(1)) #????
#       2 plot_results(x.detach(), grad_solutions, predicted_grads.detach(), num_samples_to_plot=3)
#
# Cell In[5], line 66, in DeepONet.grad_forward(self, branch_in, x)
#      63 grad_trunk = torch.zeros_like(trunk_output)
#      65 for i in range(trunk_output.shape[1]):
# ---> 66     grad_trunk[:, i] =  torch.autograd.grad(self.trunk_net(x)[i], x, create_graph = True)[0] # gradient of trunk_output[:, i] at the points x
#      67 if self.bc:
#      68     grad_trunk = grad_trunk #??? update for new formula
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\elena\Documents\GitHub\MLCS_2025-2026\lab4_deepONet\DNN.py:46, in DeepNet.forward(self, x)
#      44     x = x.unsqueeze(-1) # add a dimension at the end
#      45 for i in range(self.L):
# ---> 46     x = self.hidden[i](x)
#      47     x = self.activation(x)
#      49 if self.output is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\utils\_device.py:103, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     101 if func in _device_constructors() and kwargs.get("device") is None:
#     102     kwargs["device"] = self.device
# --> 103 return func(*args, **kwargs)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (64x1 and 64x50)

# %% [markdown]
# Finally, we look at the behaviour on new data, not contained in the training set. We start by loading the data

# %%
x_test = torch.load("data/x_test.pt")
coefs_test = torch.load("data/a_test.pt")
solutions_test = torch.load("data/u_test.pt")
grad_solutions_test = torch.load("data/gradu_test.pt")
# see the dimension of the data
print("Dimension of x: ", x_test.shape)
print("Dimension of coefs: ", coefs_test.shape)
print("Dimension of solutions: ", solutions_test.shape)
print("Dimension of solutions: ", grad_solutions_test.shape)

# %% [markdown]
# Then compare function values (again, on three randomly chosen functions, this time in the test set)

# %%
predicted_solutions_test = evaluate_deeponet(model, x_test, coefs_test, solutions_test)
plot_results(x_test.detach(), solutions_test, predicted_solutions_test.detach(), num_samples_to_plot=3)

# %% [markdown]
# And gradients:

# %%
predicted_grads = model.grad_forward(coefs_test, x)
plot_results(x.detach(), grad_solutions_test, predicted_grads.detach(), num_samples_to_plot=3)
