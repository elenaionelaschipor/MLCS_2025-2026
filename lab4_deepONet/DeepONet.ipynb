# %% [markdown]
# # Lab 4 - DeepONets
# DeepONets are neural network architectures designed to learn operators (i.e., mappings between functions). Consider the one dimensional boundary value problem
# $$
# \begin{aligned}
# \nabla\cdot\left(a\nabla u^a\right) &= f \quad \text{in } (0,1)=:\Omega\\
# u(0) = u(1) &= 0.
# \end{aligned}
# $$
# For some value $a_{\min{}}$, we define the admissible data set
# $$
# \mathcal{A} = \left\{a\in L^\infty(\Omega) : a(x)\geq a_{\min{}}\text{ almost everywhere}\right\}
# $$
# and the solution operator
# $$
# \mathcal{S}:
# \begin{cases} \mathcal{A} \to H^1_0(\Omega)\\
# a\mapsto u^a.
# \end{cases}
# $$
# We want to approximate the operator $\mathcal{S}$ over some set $\mathcal{D}\subset\mathcal{A}$ with a deepONet $\mathcal{G}$.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from DNN import DeepNet 
from utilities import plot_data, plot_results, LprelLoss

torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.set_default_dtype(torch.float64)
# Out:
# I'm using:  cpu

# %% [markdown]
# # Data Loading
# We fix $f=1$ and consider the data set
# $$
# \mathcal{D} = \left\{ a(x) = 1+\sum_{i=1}^3 y_i \mathbb{1}_{((i-1)/3, i/3)}(x): y_i\in (0,8)\right\}
# $$
# And solve the problem with linear finite elements. The code to solve the problem is given in the files `FEsolver.py` and `data_gen.ipynb`, though these require installing `FEniCSx`. To use the data, you can also load it from the respective files, that contain
# - coordinates $x_1, \dots, x_M$
# - coefficient values $a(x_1), \dots, a(x_M)$
# - solution values $u(x_1), \dots, u(x_M)$
# - solution gradient $u'(x_1), \dots, u'(x_M)$.

# %%
x = torch.load("data/x_train.pt")
coefs = torch.load("data/a_train.pt")
solutions = torch.load("data/u_train.pt")
grad_solutions = torch.load("data/gradu_train.pt")

# check the dimension of the data
print("Dimension of x: ", x.shape)
print("Dimension of coefs: ", coefs.shape)
print("Dimension of solutions: ", solutions.shape)
print("Dimension of gradients of solutions: ", grad_solutions.shape)
# Out:
# Dimension of x:  torch.Size([64])
# Dimension of coefs:  torch.Size([250, 64])
# Dimension of solutions:  torch.Size([250, 64])
# Dimension of gradients of solutions:  torch.Size([250, 64])

# %% [markdown]
# # Plot some input-output pairs
# Use the function `plot_data` provided in `utilities.py` to plot some $(a, \mathcal{S}(a))$ pairs.

# %%
plot_data(x, {'Coefficient': coefs, 'Solution': solutions}, num_samples_to_plot=3)

# %%
plot_data(x, {'Solution': solutions, 'Gradient': grad_solutions}, num_samples_to_plot=3)

# %% [markdown]
# # DeepONet architecture
# We now define the `DeepONet` class. We will use the `DeepNet` class that we have used in the previous labs.
# A deep operator network is composed of
# - a neural network $\Phi_{\mathrm{app}} : \mathbb{R}^M\to \mathbb{R}^N$ (branch network)
# - a neural network $\Phi_{\mathrm{dec}} : \mathbb{R}^d \to \mathbb{R}^N$ (trunk network)
#
# The `forward` function will take as input a point $x\in\mathbb{R^d}$ and a vector $a_1, \dots a_M \in \mathbb{R}^M$ and return
# $$
# \mathcal{G}(\mathcal{E}(a))(x) = \Phi_{\mathrm{app}}(a_1, \dots, a_M) \cdot \Phi_{\mathrm{dec}}(x)
# $$
# An implementation detail: we want to be able to evaluate on multiple points at once: the function above should be implemented so that if instead of a single point $x$ we have $\mathbf{x} = [x_1, \dots, x_p]^\top$, the function above should return
# $$
# \Big(\Phi_{\mathrm{app}}(a_1, \dots, a_M) \cdot \Phi_{\mathrm{dec}}(x_i)\Big)_{i=1}^p.
# $$
# The function takes as input the activation functions, the dimensions $M$, $d$, the widths of the layers, the dimension $N$, and a flag `bc`. If the flag is set to `True` the forward function above is replaced by
# $$
# \Phi_{\mathrm{app}}(a_1, \dots, a_M) \cdot \big(x(1-x)\Phi_{\mathrm{dec}}(x)\big)
# $$
# so that the boundary conditions are automatically satisfied.
#
# We will also define a class method `grad_forward` that computes the derivative
# $$
# \Big(\nabla_x \mathcal{G}(\mathcal{E}(a))\Big)(x) = \Phi_{\mathrm{app}}(a_1, \dots, a_M) \cdot \Big(\nabla_x\Phi_{\mathrm{dec}}\Big)(x)
# $$
# Note that this function is not used for the training, but only to inspect the results. You can postpone its implementation (and comment the corresponding part of the code in the next sections).

# %%
# Device configuration
device = torch.device("cpu")
torch.set_default_device(device)

class DeepONet(nn.Module):
    def __init__(self, activation_branch, activation_trunk, branch_input_dim:int, trunk_input_dim:int, 
                 branch_hidden_dims:list, trunk_hidden_dims:list, num_basis:int, bc:bool=False):
        """
        DeepONet class. This class defines the architecture of the DeepONet.
        The DeepONet is composed of two subnetworks: the branch network and the trunk network.
        
        Args:
        activation: activation function
        branch_input_dim: input dimension of the branch network
        trunk_input_dim: input dimension of the trunk network
        branch_hidden_dims: list of the hidden dimensions of the branch network
        trunck_hidden_dims: list of the hidden dimensions of the trunk network
        num_basis: number of basis functions
        bc: boolean, if True, we multiply the output of the trunk network by x*(1-x) to satisfy the boundary condition
        """
        super(DeepONet, self).__init__()

        # The output dimension of the trunk network must be equal to the number of basis functions.
        assert trunk_hidden_dims[-1] == num_basis 

        self.activation_branch = activation_branch # initialize the branch activation function
        self.activation_trunk = activation_trunk # initialize the trunk activation function
        self.bc = bc # store the bc flag
        self.branch_net = DeepNet(activation_branch, branch_input_dim, branch_hidden_dims) # create the approximation network
        self.trunk_net = DeepNet(activation_trunk, trunk_input_dim, trunk_hidden_dims)  # create the decoding network

    def forward(self, branch_in, x):
        # compute the output of the approximation and decoding NNs
        print("evaluating branch output ------------------------------------------------------ ")
        print("branch_in shape: ", branch_in.shape)
        print(self.branch_net)
        branch_output = self.branch_net.forward(torch.transpose(branch_in, 0, 1)) # output of the branch network  
        print("done1------------------------------------------------------ ")
        print(self.trunk_net)
        print(x.unsqueeze(-1).shape)
        trunk_output = self.trunk_net.forward(torch.transpose(x.unsqueeze(-1), 0, 1)) # output of the trunk network
        print("done2------------------------------------------------------ ")
        


        if self.bc:
            print("applying bc ------------------------------------------------------ ")
            trunk_output = trunk_output * x * (1 - x)  # update for new formula
            return torch.sum(branch_output * trunk_output, dim=1, keepdim=True)
        else:
            print("no bc ------------------------------------------------------ ")
            # print(branch_output.shape, trunk_output.shape)
            print(torch.sum(branch_output * trunk_output, dim=1, keepdim=True))
            print("okay ------------------------------------------------------ ")
            return torch.transpose(torch.sum(branch_output * trunk_output, dim=1, keepdim=True), 0, 1)

    def grad_forward(self, branch_in, x):
        # compute the gradient of the ONet at the points x
        x.requires_grad_(True)
        branch_output = self.branch_net.forward(branch_in)
        trunk_output = self.trunk_net.forward(x)

        grad_trunk = torch.zeros_like(trunk_output)

        for i in range(trunk_output.shape[1]):
            grad_trunk[:, i] =  torch.autograd.grad(self.trunk_net(x)[i], x, create_graph = True)[0] # gradient of trunk_output[:, i] at the points x
        if self.bc:
            grad_trunk = grad_trunk #??? update for new formula
            return None #...
        else:
            return branch_output * grad_trunk

# %% [markdown]
# We now define a DeepONet with proper input dimensions, an activation function (choose one and play with different activation functions), where both trunk and branch nets have a total of `3` layers with hidden dimension `50` and `output_dim = num_basis = 80`.

# %%
d = int(x.shape[0])
M = int(coefs.shape[0])

# %%
# Initialize the model # activation_branch, activation_trunk, branch_input_dim:int, trunk_input_dim:int, 
                 # branch_hidden_dims:list, trunk_hidden_dims:list, num_basis:int,
FNN = DeepNet(torch.nn.Tanh(), 1, [5,5,5], 1)  #ok
model = DeepONet(torch.nn.Tanh(), torch.nn.Tanh(), M, d, [50,80], [50,80], 80).to(device)

model
# Out:
# DeepONet(
#   (activation_branch): Tanh()
#   (activation_trunk): Tanh()
#   (branch_net): DeepNet(
#     (activation): Tanh()
#     (hidden): ModuleList(
#       (0): Linear(in_features=250, out_features=50, bias=True)
#       (1): Linear(in_features=50, out_features=80, bias=True)
#     )
#   )
#   (trunk_net): DeepNet(
#     (activation): Tanh()
#     (hidden): ModuleList(
#       (0): Linear(in_features=64, out_features=50, bias=True)
#       (1): Linear(in_features=50, out_features=80, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Training
# We choose the number of epochs and the meta parameters of the training algorithm. We use adam with `MSELoss` to compute the distance between the exact and predicted values.

# %%
# train the model
num_epochs = int(5000)
learning_rate = 5e-4
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1250, gamma=0.5)

# Choose a criterion
criterion = nn.MSELoss()
# criterion = LprelLoss(2, True)

# %% [markdown]
# We introduce the funciton that performs the training.

# %%
def train_deeponet(model, x, rhs, solutions, num_epochs, loss_values):
    model.train()
    for epoch in range(num_epochs):

        optimizer.zero_grad() # Zero the gradients
        print(rhs)
        output = model(rhs.to(device), x.to(device)) # Forward pass
        print("hi?? ------------------------------------------------------ ")
        print("output", output.shape)
        print('solutions', solutions.to(device).shape)
        loss = criterion(output, solutions.to(device))
        print("hello! ------------------------------------------------------ ")
        loss.backward() # Backward pass
        optimizer.step() # Update the weights
        loss_values.append(loss.cpu().detach().numpy()) # Store the loss

        if (epoch + 1) % 100 == 0:
            print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4e}')

    return loss_values

# %% [markdown]
# ## Training the deepONet
#
# The following block of code trains the model for a number of epochs equals to `num_epochs`. Note that if you rerun this block the training of the model **continues** for other `num_epochs` epochs.

# %%
try:
    print(f"We have already trained the model for {len(loss_values)} epochs.")
except:
    loss_values = []
    
loss_values = train_deeponet(model, x, coefs, solutions, num_epochs, loss_values)
# Out:
# We have already trained the model for 4331 epochs.
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[6.6643e-05],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [6.6643e-05]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-1.4407e-04],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 5.4045e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 9.4312e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [ 5.2492e-01],
#         [-1.4407e-04]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-4.9522e-05],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [-4.9522e-05]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[1.6121e-04],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [5.4077e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [9.4344e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [5.2524e-01],
#         [1.6121e-04]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[1.0049e-04],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [5.4069e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [1.0049e-04]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-8.0080e-05],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 5.4049e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 9.4316e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [ 5.2496e-01],
#         [-8.0080e-05]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-2.3519e-05],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 9.4322e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [-2.3519e-05]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[1.5043e-04],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [5.4073e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [9.4341e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [5.2521e-01],
#         [1.5043e-04]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[1.1439e-04],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [5.4068e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [5.2517e-01],
#         [1.1439e-04]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-3.8329e-05],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 5.4051e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 9.4320e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [ 5.2500e-01],
#         [-3.8329e-05]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-8.2627e-06],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 5.4054e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [-8.2627e-06]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[1.3360e-04],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [5.4070e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [9.4339e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [5.2518e-01],
#         [1.3360e-04]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[1.1427e-04],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [1.1427e-04]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-1.3449e-05],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 5.4053e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 9.4323e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [ 5.2502e-01],
#         [-1.3449e-05]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-1.1164e-06],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 5.4055e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 9.4324e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [ 5.2503e-01],
#         [-1.1164e-06]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[1.1360e-04],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [5.4067e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [9.4337e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [5.2516e-01],
#         [1.1360e-04]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[1.0530e-04],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [5.4066e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [9.4336e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [5.2515e-01],
#         [1.0530e-04]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# ...
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-3.3568e-06],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [-3.3568e-06]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[9.1390e-07],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [5.4061e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [9.4330e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [9.1390e-07]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[1.6651e-06],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [5.4062e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [9.4331e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [5.2510e-01],
#         [1.6651e-06]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# tensor([[0.0748, 0.1413, 0.1413,  ..., 0.1131, 0.1131, 0.0748],
#         [0.0662, 0.1266, 0.1266,  ..., 0.1133, 0.1133, 0.0662],
#         [0.0548, 0.1930, 0.1930,  ..., 0.0884, 0.0884, 0.0548],
#         ...,
#         [0.0606, 0.0801, 0.0801,  ..., 0.1803, 0.1803, 0.0606],
#         [0.0409, 0.1700, 0.1700,  ..., 0.1237, 0.1237, 0.0409],
#         [0.0350, 0.1487, 0.1487,  ..., 0.1136, 0.1136, 0.0350]])
# evaluating branch output ------------------------------------------------------
# branch_in shape:  torch.Size([250, 64])
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=250, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# done1------------------------------------------------------
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=64, out_features=50, bias=True)
#     (1): Linear(in_features=50, out_features=80, bias=True)
#   )
# )
# torch.Size([64, 1])
# done2------------------------------------------------------
# no bc ------------------------------------------------------
# tensor([[-1.8331e-06],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 5.4061e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 9.4330e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [ 5.2509e-01],
#         [-1.8331e-06]], grad_fn=<SumBackward1>)
# okay ------------------------------------------------------
# hi?? ------------------------------------------------------
# output torch.Size([1, 64])
# solutions torch.Size([250, 64])
# hello! ------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 6
#       3 except:
#       4     loss_values = []
# ----> 6 loss_values = train_deeponet(model, x, coefs, solutions, num_epochs, loss_values)
#
# Cell In[56], line 14, in train_deeponet(model, x, rhs, solutions, num_epochs, loss_values)
#      12 print("hello! ------------------------------------------------------ ")
#      13 loss.backward() # Backward pass
# ---> 14 optimizer.step() # Update the weights
#      15 loss_values.append(loss.cpu().detach().numpy()) # Store the loss
#      17 if (epoch + 1) % 100 == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\optim\lr_scheduler.py:133, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     131 opt = opt_ref()
#     132 opt._opt_called = True  # type: ignore[union-attr]
# --> 133 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\optim\optimizer.py:516, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     511         else:
#     512             raise RuntimeError(
#     513                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     514             )
# --> 516 out = func(*args, **kwargs)
#     517 self._optimizer_step_code()
#     519 # call optimizer step post hooks
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\optim\optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\optim\adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)    244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\optim\optimizer.py:149, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     147     return disabled_func(*args, **kwargs)
#     148 else:
# --> 149     return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\optim\adam.py:949, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     946 else:
#     947     func = _single_tensor_adam
# --> 949 func(
#     950     params,
#     951     grads,
#     952     exp_avgs,
#     953     exp_avg_sqs,
#     954     max_exp_avg_sqs,
#     955     state_steps,
#     956     amsgrad=amsgrad,
#     957     has_complex=has_complex,
#     958     beta1=beta1,
#     959     beta2=beta2,
#     960     lr=lr,
#     961     weight_decay=weight_decay,
#     962     eps=eps,
#     963     maximize=maximize,
#     964     capturable=capturable,
#     965     differentiable=differentiable,
#     966     grad_scale=grad_scale,
#     967     found_inf=found_inf,
#     968     decoupled_weight_decay=decoupled_weight_decay,
#     969 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\optim\adam.py:464, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     462         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     463 else:
# --> 464     exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     466 if capturable or differentiable:
#     467     step = step_t
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\utils\_device.py:103, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     101 if func in _device_constructors() and kwargs.get("device") is None:
#     102     kwargs["device"] = self.device
# --> 103 return func(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# Plot the loss function during the training

# %%
plt.semilogy(range(len(loss_values)), loss_values)
plt.grid()

# %% [markdown]
# # (Qualitative) evaluation of the trained deepONet
#
# The following function computes the predicted values on some coefficients and the corresponding loss.

# %%
def evaluate_deeponet(model, x, coefs, solutions):
    model.eval()
    with torch.no_grad():
        u_pred = model(coefs.to(device), x.to(device))
        loss = criterion(u_pred, solutions.to(device))
        print(f'Loss: {loss.item():.4e}')
    return u_pred

# %% [markdown]
# We then plot the comparison on three random functions from the training set. Launching the code again will show (potentially) new functions.

# %%
# Plot results
predicted_solutions = evaluate_deeponet(model, x, coefs, solutions)
print(solutions.shape)
plot_results(x.detach(), solutions, predicted_solutions.detach(), num_samples_to_plot=3)

# %% [markdown]
# We now do the same thing with the gradients, still comparing with functions in the training set.

# %%
predicted_grads = model.grad_forward(coefs, x)
plot_results(x.detach(), grad_solutions, predicted_grads.detach(), num_samples_to_plot=3)

# %% [markdown]
# Finally, we look at the behaviour on new data, not contained in the training set. We start by loading the data

# %%
x_test = torch.load("data/x_test.pt")
coefs_test = torch.load("data/a_test.pt")
solutions_test = torch.load("data/u_test.pt")
grad_solutions_test = torch.load("data/gradu_test.pt")
# see the dimension of the data
print("Dimension of x: ", x_test.shape)
print("Dimension of coefs: ", coefs_test.shape)
print("Dimension of solutions: ", solutions_test.shape)
print("Dimension of solutions: ", grad_solutions_test.shape)

# %% [markdown]
# Then compare function values (again, on three randomly chosen functions, this time in the test set)

# %%
predicted_solutions_test = evaluate_deeponet(model, x_test, coefs_test, solutions_test)
plot_results(x_test.detach(), solutions_test, predicted_solutions_test.detach(), num_samples_to_plot=3)

# %% [markdown]
# And gradients:

# %%
predicted_grads = model.grad_forward(coefs_test, x)
plot_results(x.detach(), grad_solutions_test, predicted_grads.detach(), num_samples_to_plot=3)
