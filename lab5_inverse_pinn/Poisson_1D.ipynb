# %% [markdown]
# # Solving an Inverse Problem with Physics-Informed Neural Networks (PINNs)
#
# ###Problem Statement:
# We aim to find the scalar parameter $\alpha \in \mathbb{R}$ given a target function $\tilde{u}$. Specifically, we want to solve the following optimization problem:
# $$
# \text{arg}\min f(u,\tilde{u}) = \| u - \tilde{u} \|^2,
# $$
# where $u$ satisfies the boundary value problem described by a second-order Partial differential equation (PDE):
# \begin{cases}
# \displaystyle -\alpha \frac{d^2u}{dx^2} = f(x), \quad x \in \Omega = (0,1),\\​
#  u(0) = u(1) =  0 .
# \end{cases}
#
# ### Given data:
# The target function $\tilde{u}$ is given by:
# $$\tilde{u} = \sin(\pi x)$$
#
# The function $f(x)$, derived from the assumed true solution, is specified as:
# $$f = 2 \pi^2 \sin(\pi x).$$
#
# $\alpha$ should be =2?
#
#
# -----------------------------
#
# # Objective
#
# Our goal is to compute the value of $\alpha$ that best aligns the solution $u(x)$ of the PDE with the given $\tilde{u}(x)$.
# To achieve this, we can utilize a Physics-Informed Neural Network (PINN) that integrates the differential equation as a part of its loss function.
# This approach ensures that the learned solution not fits the data while respecting the underlying "physics" described by the PDE.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from DNN import DeepNet

torch.autograd.set_detect_anomaly(True)
torch.manual_seed(128)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.set_default_device(device)

# %%
def convert(x):
  return x.cpu().detach().numpy()

# %% [markdown]
# # Define the PINN model
# we need to define the following components:
# - The neural network architecture to approximate the solution $u(x)$.
# - A parameter $\alpha$ to be optimized to approximate the parameter $\alpha$.

# %%
# provo come nell'altro?? 0 instructions here

# %%
input = 1
output = 1
hidden_layer = [40, 40, 40, 40, 40]
activation_function = torch.nn.Tanh()

FNN = DeepNet(activation_function, input, hidden_layer,output).to(device)
alpha = nn.Parameter().to(device)
FNN
# Out:
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=1, out_features=40, bias=True)
#     (1-4): 4 x Linear(in_features=40, out_features=40, bias=True)
#   )
#   (output): Linear(in_features=40, out_features=1, bias=False)
# )

# %% [markdown]
# # Define the points for training

# %%
x0 = torch.Tensor([0.0]).to(device)
x1 = torch.Tensor([1.0]).to(device)
u_b0 = torch.Tensor([0.0]).to(device)
u_b1 = torch.Tensor([0.0]).to(device)

n_train_points =  150 # for train
n_data_points  = 100 # for data interpolation
n_test_points  = 50 # for test

x_train = torch.linspace(x0[0], x1[0], n_train_points).to(device)
x_data = torch.linspace(x0[0], x1[0], n_data_points).to(device)
x_test = torch.linspace(x0[0], x1[0], n_test_points).to(device)

# %%
plt.figure(figsize=(8, 1),num =1)  
plt.scatter(convert(x_train), np.zeros_like(convert(x_train)), color='red', s=50, marker='x', label='Collocation Points')
plt.scatter(convert(x_data), np.zeros_like(convert(x_data)), color='blue', s=50, marker='.', label='Data Points')

plt.scatter(convert(x0), np.zeros_like(convert(x0)), color='green', s=50)
plt.scatter(convert(x1), np.zeros_like(convert(x1)), color='green', s=50)
plt.xlabel('x')
plt.yticks([])  
plt.title('Collocation Points')
# Out:
# Text(0.5, 1.0, 'Collocation Points')

# %% [markdown]
# # Define the exact solution and the rhs of the PDE

# %%
def exact_sol(x):
    return torch.sin(np.pi*x)

alpha_exact = 2.0

def rhs(x):
    return 2*np.pi**2 * torch.sin(np.pi*x)

u_exact_train = exact_sol(x_train)
rhs_train = rhs(x_train)
u_exact_data = exact_sol(x_data)
u_exact_test = exact_sol(x_test)

# %% [markdown]
# # Define the loss function

# %%
def eval_loss_ode(Phi,x,rhs,alpha,metric):
    x.requires_grad_(True)

    u_NN = Phi(x)
    u_NN_x = torch.autograd.grad(u_NN.sum(), x, create_graph=True)[0]
    u_NN_xx = torch.autograd.grad(u_NN_x.sum(), x, create_graph=True)[0]

    return metric(-alpha * u_NN_xx, rhs)

def eval_loss_pt(Phi,x,y):
    return torch.nn.MSELoss()(Phi(x), y)
    
def eval_loss_data(Phi,x,data,metric):
    return metric(Phi(x), data)

# %% [markdown]
# # Train the model

# %%
n_epochs = 10000
learining_rate = 1e-3
alpha = nn.Parameter(torch.Tensor([1]).to(device).requires_grad_(True)) #! what this carefully

optimizer = optim.Adam(list(FNN.parameters())+[alpha],lr = 1e-3) #! what this carefully   # huh?????
scheduler = torch.optim.lr_scheduler.StepLR(optimizer,5000,0.5) 

loss_values = np.empty([n_epochs+1,5]) #total,ode, b0,b1, data
alpha_values = np.empty([n_epochs+1])

MSE =  torch.nn.MSELoss()
STEP = 100 #save every 100 epochs

assert n_epochs%STEP == 0

err = np.empty([int(n_epochs/STEP)+1,2])
u_animate =  np.empty([int(n_epochs/STEP)+1,n_train_points])
err_animate = np.empty([int(n_epochs/STEP)+1,n_train_points])
k = 0 

for epoch in range(n_epochs+1):

    loss_ode = eval_loss_ode(FNN, x_train, rhs_train, alpha, MSE)
    loss_b0 = eval_loss_pt(FNN, x_train[0].unsqueeze(-1), u_b0)
    loss_b1 = eval_loss_pt(FNN, x_train[-1].unsqueeze(-1), u_b1)

    loss_data = eval_loss_data(FNN, x_data, u_exact_data, MSE)
    loss_alpha = MSE(alpha, torch.tensor([alpha_exact]).to(device))

    loss = loss_ode + loss_b0 + loss_b1 + loss_data + loss_alpha

    # optimizer zero grad
    optimizer.zero_grad()
    
    # loss backward
    loss.backward()
    
    # optimizer step
    optimizer.step()
    
    # scheduler step
    scheduler.step()
    

    loss_values[epoch,:] = np.stack([convert(loss),convert(loss_ode),convert(loss_b0),convert(loss_b1),convert(loss_data)])
    alpha_values[epoch] = alpha
    if epoch%STEP == 0:
      lr = np.array(scheduler.get_last_lr())
    #   u_NN_test =  FNN(x_test)
    #   err[k,:] = [L2_diff(convert(FNN(x_train)),u_exact_train), L2_diff(convert(u_NN_test),u_exact_test)]
    #   u_animate[k,:]  = convert(FNN(x_sort_train).squeeze())
    #   err_animate[k,:]= (np.abs(u_animate[k,:] - u_exact_train_sort.squeeze()))
      print(f'Epoch {epoch} || learning rate {lr.squeeze():.2e} ''\n'
            f'Global loss {loss_values[epoch,0]:.2e} || loss ode {loss_values[epoch,1]:.2e} || loss b0 {loss_values[epoch,2]:.2e} || loss b1 {loss_values[epoch,3]:.2e} || loss data {loss_values[epoch,4]:.2e}','\n')
      k+=1
# Out:
# Epoch 0 || learning rate 1.00e-03
# Global loss 1.29e+01 || loss ode 6.85e+00 || loss b0 2.50e+00 || loss b1 1.08e+00 || loss data 1.51e+00
#
# Epoch 100 || learning rate 1.00e-03
# Global loss 1.61e+00 || loss ode 2.30e-02 || loss b0 2.91e-02 || loss b1 4.00e-02 || loss data 6.04e-01
#
# Epoch 200 || learning rate 1.00e-03
# Global loss 1.48e+00 || loss ode 4.49e-03 || loss b0 3.28e-02 || loss b1 3.21e-02 || loss data 5.59e-01
#
# Epoch 300 || learning rate 1.00e-03
# Global loss 1.36e+00 || loss ode 3.30e-03 || loss b0 2.95e-02 || loss b1 2.63e-02 || loss data 5.17e-01
#
# Epoch 400 || learning rate 1.00e-03
# Global loss 1.23e+00 || loss ode 2.74e-03 || loss b0 2.49e-02 || loss b1 2.20e-02 || loss data 4.77e-01
#
# Epoch 500 || learning rate 1.00e-03
# Global loss 1.12e+00 || loss ode 2.41e-03 || loss b0 2.07e-02 || loss b1 1.83e-02 || loss data 4.41e-01
#
# Epoch 600 || learning rate 1.00e-03
# Global loss 1.01e+00 || loss ode 2.20e-03 || loss b0 1.71e-02 || loss b1 1.51e-02 || loss data 4.09e-01
#
# Epoch 700 || learning rate 1.00e-03
# Global loss 9.07e-01 || loss ode 2.00e-03 || loss b0 1.41e-02 || loss b1 1.23e-02 || loss data 3.81e-01
#
# Epoch 800 || learning rate 1.00e-03
# Global loss 8.15e-01 || loss ode 1.80e-03 || loss b0 1.15e-02 || loss b1 9.99e-03 || loss data 3.57e-01
#
# Epoch 900 || learning rate 1.00e-03
# Global loss 7.32e-01 || loss ode 1.61e-03 || loss b0 9.34e-03 || loss b1 8.13e-03 || loss data 3.35e-01
#
# Epoch 1000 || learning rate 1.00e-03
# Global loss 6.58e-01 || loss ode 1.46e-03 || loss b0 7.54e-03 || loss b1 6.63e-03 || loss data 3.17e-01
#
# Epoch 1100 || learning rate 1.00e-03
# Global loss 5.92e-01 || loss ode 1.32e-03 || loss b0 6.09e-03 || loss b1 5.36e-03 || loss data 3.00e-01
#
# Epoch 1200 || learning rate 1.00e-03
# Global loss 5.33e-01 || loss ode 1.18e-03 || loss b0 4.88e-03 || loss b1 4.32e-03 || loss data 2.86e-01
#
# Epoch 1300 || learning rate 1.00e-03
# Global loss 4.86e-01 || loss ode 4.99e-03 || loss b0 4.55e-03 || loss b1 2.75e-03 || loss data 2.74e-01
#
# Epoch 1400 || learning rate 1.00e-03
# Global loss 4.60e-01 || loss ode 2.44e-02 || loss b0 1.82e-03 || loss b1 4.56e-03 || loss data 2.63e-01
#
# Epoch 1500 || learning rate 1.00e-03
# Global loss 4.60e-01 || loss ode 6.28e-02 || loss b0 8.48e-04 || loss b1 5.04e-03 || loss data 2.54e-01
#
# Epoch 1600 || learning rate 1.00e-03
# Global loss 3.62e-01 || loss ode 7.50e-04 || loss b0 1.92e-03 || loss b1 1.69e-03 || loss data 2.46e-01
#
# Epoch 1700 || learning rate 1.00e-03
# Global loss 3.40e-01 || loss ode 7.87e-03 || loss b0 1.93e-03 || loss b1 9.40e-04 || loss data 2.39e-01
#
# Epoch 1800 || learning rate 1.00e-03
# Global loss 3.26e-01 || loss ode 1.96e-02 || loss b0 5.70e-04 || loss b1 2.05e-03 || loss data 2.32e-01
#
# Epoch 1900 || learning rate 1.00e-03
# Global loss 2.86e-01 || loss ode 6.11e-04 || loss b0 8.52e-04 || loss b1 7.83e-04 || loss data 2.27e-01
#
# Epoch 2000 || learning rate 1.00e-03
# Global loss 2.69e-01 || loss ode 1.75e-03 || loss b0 8.07e-04 || loss b1 3.68e-04 || loss data 2.22e-01
#
# Epoch 2100 || learning rate 1.00e-03
# Global loss 2.85e-01 || loss ode 3.31e-02 || loss b0 1.44e-03 || loss b1 8.27e-05 || loss data 2.18e-01
#
# Epoch 2200 || learning rate 1.00e-03
# Global loss 2.40e-01 || loss ode 5.01e-04 || loss b0 3.48e-04 || loss b1 2.91e-04 || loss data 2.14e-01
#
# Epoch 2300 || learning rate 1.00e-03
# Global loss 2.31e-01 || loss ode 2.12e-03 || loss b0 3.42e-04 || loss b1 9.64e-05 || loss data 2.11e-01
#
# Epoch 2400 || learning rate 1.00e-03
# Global loss 2.22e-01 || loss ode 1.40e-03 || loss b0 1.24e-04 || loss b1 2.15e-04 || loss data 2.08e-01
#
# Epoch 2500 || learning rate 1.00e-03
# Global loss 2.15e-01 || loss ode 5.10e-04 || loss b0 1.04e-04 || loss b1 1.09e-04 || loss data 2.06e-01
#
# Epoch 2600 || learning rate 1.00e-03
# Global loss 2.16e-01 || loss ode 6.37e-03 || loss b0 2.04e-05 || loss b1 3.63e-04 || loss data 2.04e-01
#
# Epoch 2700 || learning rate 1.00e-03
# Global loss 2.06e-01 || loss ode 9.28e-04 || loss b0 6.54e-05 || loss b1 1.20e-05 || loss data 2.02e-01
#
# Epoch 2800 || learning rate 1.00e-03
# Global loss 2.02e-01 || loss ode 5.28e-04 || loss b0 2.05e-05 || loss b1 2.26e-05 || loss data 2.00e-01
#
# Epoch 2900 || learning rate 1.00e-03
# Global loss 2.00e-01 || loss ode 8.81e-04 || loss b0 3.08e-05 || loss b1 1.62e-07 || loss data 1.98e-01
#
# Epoch 3000 || learning rate 1.00e-03
# Global loss 1.98e-01 || loss ode 6.73e-04 || loss b0 1.39e-06 || loss b1 9.82e-06 || loss data 1.97e-01
#
# Epoch 3100 || learning rate 1.00e-03
# Global loss 1.97e-01 || loss ode 4.73e-04 || loss b0 1.69e-06 || loss b1 3.05e-08 || loss data 1.96e-01
#
# Epoch 3200 || learning rate 1.00e-03
# Global loss 2.13e-01 || loss ode 1.55e-02 || loss b0 4.12e-06 || loss b1 2.56e-04 || loss data 1.97e-01
#
# Epoch 3300 || learning rate 1.00e-03
# Global loss 1.96e-01 || loss ode 1.07e-03 || loss b0 4.96e-06 || loss b1 1.84e-06 || loss data 1.95e-01
#
# Epoch 3400 || learning rate 1.00e-03
# Global loss 1.95e-01 || loss ode 2.89e-04 || loss b0 1.19e-06 || loss b1 3.18e-06 || loss data 1.94e-01
#
# Epoch 3500 || learning rate 1.00e-03
# Global loss 1.97e-01 || loss ode 2.67e-03 || loss b0 3.42e-06 || loss b1 2.15e-05 || loss data 1.94e-01
#
# Epoch 3600 || learning rate 1.00e-03
# Global loss 1.95e-01 || loss ode 9.03e-04 || loss b0 3.58e-06 || loss b1 2.42e-05 || loss data 1.93e-01
#
# Epoch 3700 || learning rate 1.00e-03
# Global loss 1.95e-01 || loss ode 1.28e-03 || loss b0 2.20e-05 || loss b1 3.45e-08 || loss data 1.93e-01
#
# Epoch 3800 || learning rate 1.00e-03
# Global loss 1.94e-01 || loss ode 8.09e-04 || loss b0 2.67e-06 || loss b1 2.88e-05 || loss data 1.93e-01
#
# Epoch 3900 || learning rate 1.00e-03
# Global loss 1.94e-01 || loss ode 2.90e-04 || loss b0 9.46e-06 || loss b1 1.55e-05 || loss data 1.92e-01
#
# Epoch 4000 || learning rate 1.00e-03
# Global loss 1.94e-01 || loss ode 3.54e-04 || loss b0 7.06e-06 || loss b1 1.68e-05 || loss data 1.92e-01
#
# Epoch 4100 || learning rate 1.00e-03
# Global loss 1.98e-01 || loss ode 3.87e-03 || loss b0 5.50e-05 || loss b1 8.70e-07 || loss data 1.92e-01
#
# Epoch 4200 || learning rate 1.00e-03
# Global loss 3.43e-01 || loss ode 1.48e-01 || loss b0 9.26e-04 || loss b1 7.19e-04 || loss data 1.92e-01
#
# Epoch 4300 || learning rate 1.00e-03
# Global loss 2.44e-01 || loss ode 5.11e-02 || loss b0 5.03e-04 || loss b1 2.68e-05 || loss data 1.91e-01
#
# Epoch 4400 || learning rate 1.00e-03
# Global loss 1.95e-01 || loss ode 1.41e-03 || loss b0 2.99e-06 || loss b1 3.82e-05 || loss data 1.92e-01
#
# Epoch 4500 || learning rate 1.00e-03
# Global loss 2.71e-01 || loss ode 7.71e-02 || loss b0 5.67e-04 || loss b1 2.47e-04 || loss data 1.91e-01
#
# Epoch 4600 || learning rate 1.00e-03
# Global loss 2.43e-01 || loss ode 4.89e-02 || loss b0 3.39e-04 || loss b1 1.76e-04 || loss data 1.92e-01
#
# Epoch 4700 || learning rate 1.00e-03
# Global loss 2.19e-01 || loss ode 2.48e-02 || loss b0 5.49e-05 || loss b1 1.09e-04 || loss data 1.92e-01
#
# Epoch 4800 || learning rate 1.00e-03
# Global loss 2.42e-01 || loss ode 4.81e-02 || loss b0 3.30e-04 || loss b1 1.44e-04 || loss data 1.92e-01
#
# Epoch 4900 || learning rate 1.00e-03
# Global loss 2.13e-01 || loss ode 1.89e-02 || loss b0 1.74e-04 || loss b1 4.01e-05 || loss data 1.92e-01
#
# Epoch 5000 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 2.56e-04 || loss b0 2.04e-05 || loss b1 1.77e-05 || loss data 1.92e-01
#
# Epoch 5100 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 2.24e-04 || loss b0 1.84e-05 || loss b1 2.01e-05 || loss data 1.92e-01
#
# Epoch 5200 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 2.20e-04 || loss b0 1.86e-05 || loss b1 2.03e-05 || loss data 1.92e-01
#
# Epoch 5300 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 2.16e-04 || loss b0 1.88e-05 || loss b1 2.05e-05 || loss data 1.92e-01
#
# Epoch 5400 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 2.12e-04 || loss b0 1.90e-05 || loss b1 2.06e-05 || loss data 1.92e-01
#
# Epoch 5500 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 2.08e-04 || loss b0 1.91e-05 || loss b1 2.07e-05 || loss data 1.92e-01
#
# Epoch 5600 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 2.03e-04 || loss b0 1.92e-05 || loss b1 2.08e-05 || loss data 1.92e-01
#
# Epoch 5700 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.99e-04 || loss b0 1.93e-05 || loss b1 2.09e-05 || loss data 1.92e-01
#
# Epoch 5800 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.94e-04 || loss b0 1.93e-05 || loss b1 2.10e-05 || loss data 1.92e-01
#
# Epoch 5900 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.90e-04 || loss b0 1.94e-05 || loss b1 2.10e-05 || loss data 1.92e-01
#
# Epoch 6000 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.85e-04 || loss b0 1.94e-05 || loss b1 2.11e-05 || loss data 1.92e-01
#
# Epoch 6100 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.80e-04 || loss b0 1.95e-05 || loss b1 2.11e-05 || loss data 1.92e-01
#
# Epoch 6200 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.75e-04 || loss b0 1.95e-05 || loss b1 2.11e-05 || loss data 1.92e-01
#
# Epoch 6300 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.71e-04 || loss b0 1.95e-05 || loss b1 2.11e-05 || loss data 1.92e-01
#
# Epoch 6400 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.66e-04 || loss b0 1.96e-05 || loss b1 2.11e-05 || loss data 1.92e-01
#
# Epoch 6500 || learning rate 5.00e-04
# Global loss 2.23e-01 || loss ode 2.80e-02 || loss b0 2.10e-06 || loss b1 6.30e-07 || loss data 1.94e-01
#
# Epoch 6600 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.82e-04 || loss b0 1.99e-05 || loss b1 2.02e-05 || loss data 1.92e-01
#
# Epoch 6700 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.64e-04 || loss b0 1.92e-05 || loss b1 2.06e-05 || loss data 1.92e-01
#
# Epoch 6800 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.59e-04 || loss b0 1.93e-05 || loss b1 2.07e-05 || loss data 1.92e-01
#
# Epoch 6900 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.55e-04 || loss b0 1.94e-05 || loss b1 2.08e-05 || loss data 1.92e-01
#
# Epoch 7000 || learning rate 5.00e-04
# Global loss 2.20e-01 || loss ode 2.59e-02 || loss b0 5.29e-04 || loss b1 2.47e-05 || loss data 1.92e-01
#
# Epoch 7100 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.57e-04 || loss b0 1.95e-05 || loss b1 2.07e-05 || loss data 1.92e-01
#
# Epoch 7200 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.52e-04 || loss b0 1.95e-05 || loss b1 2.07e-05 || loss data 1.92e-01
#
# Epoch 7300 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.48e-04 || loss b0 1.96e-05 || loss b1 2.08e-05 || loss data 1.92e-01
#
# Epoch 7400 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.44e-04 || loss b0 1.96e-05 || loss b1 2.09e-05 || loss data 1.92e-01
#
# Epoch 7500 || learning rate 5.00e-04
# Global loss 1.95e-01 || loss ode 1.03e-03 || loss b0 2.46e-07 || loss b1 2.08e-05 || loss data 1.92e-01
#
# Epoch 7600 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.44e-04 || loss b0 1.92e-05 || loss b1 2.08e-05 || loss data 1.92e-01
#
# Epoch 7700 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.41e-04 || loss b0 1.96e-05 || loss b1 2.07e-05 || loss data 1.92e-01
#
# Epoch 7800 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 3.10e-04 || loss b0 2.26e-05 || loss b1 2.63e-05 || loss data 1.92e-01
#
# Epoch 7900 || learning rate 5.00e-04
# Global loss 1.98e-01 || loss ode 4.83e-03 || loss b0 7.94e-09 || loss b1 9.99e-05 || loss data 1.92e-01
#
# Epoch 8000 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.33e-04 || loss b0 1.88e-05 || loss b1 2.16e-05 || loss data 1.92e-01
#
# Epoch 8100 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.71e-04 || loss b0 1.94e-05 || loss b1 1.24e-05 || loss data 1.92e-01
#
# Epoch 8200 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.28e-04 || loss b0 1.94e-05 || loss b1 2.10e-05 || loss data 1.92e-01
#
# Epoch 8300 || learning rate 5.00e-04
# Global loss 1.95e-01 || loss ode 1.17e-03 || loss b0 4.51e-05 || loss b1 6.60e-06 || loss data 1.92e-01
#
# Epoch 8400 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.11e-04 || loss b0 1.91e-05 || loss b1 2.01e-05 || loss data 1.92e-01
#
# Epoch 8500 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.76e-04 || loss b0 1.26e-05 || loss b1 2.47e-05 || loss data 1.92e-01
#
# Epoch 8600 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 2.66e-04 || loss b0 2.68e-05 || loss b1 1.30e-05 || loss data 1.92e-01
#
# Epoch 8700 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.49e-04 || loss b0 1.80e-05 || loss b1 2.44e-05 || loss data 1.92e-01
#
# Epoch 8800 || learning rate 5.00e-04
# Global loss 1.95e-01 || loss ode 1.13e-03 || loss b0 3.75e-05 || loss b1 2.30e-06 || loss data 1.92e-01
#
# Epoch 8900 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.62e-04 || loss b0 2.14e-05 || loss b1 2.08e-05 || loss data 1.92e-01
#
# Epoch 9000 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 2.40e-04 || loss b0 2.64e-05 || loss b1 1.48e-05 || loss data 1.92e-01
#
# Epoch 9100 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.32e-04 || loss b0 2.20e-05 || loss b1 1.83e-05 || loss data 1.92e-01
#
# Epoch 9200 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.11e-04 || loss b0 1.97e-05 || loss b1 2.06e-05 || loss data 1.92e-01
#
# Epoch 9300 || learning rate 5.00e-04
# Global loss 1.95e-01 || loss ode 8.87e-04 || loss b0 4.50e-05 || loss b1 8.75e-07 || loss data 1.92e-01
#
# Epoch 9400 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.09e-04 || loss b0 1.98e-05 || loss b1 2.07e-05 || loss data 1.92e-01
#
# Epoch 9500 || learning rate 5.00e-04
# Global loss 1.96e-01 || loss ode 1.71e-03 || loss b0 4.01e-07 || loss b1 9.24e-07 || loss data 1.92e-01
#
# Epoch 9600 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.06e-04 || loss b0 1.90e-05 || loss b1 2.18e-05 || loss data 1.92e-01
#
# Epoch 9700 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.16e-04 || loss b0 2.13e-05 || loss b1 1.85e-05 || loss data 1.92e-01
#
# Epoch 9800 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.33e-04 || loss b0 1.67e-05 || loss b1 2.49e-05 || loss data 1.92e-01
#
# Epoch 9900 || learning rate 5.00e-04
# Global loss 1.94e-01 || loss ode 1.20e-04 || loss b0 1.69e-05 || loss b1 2.38e-05 || loss data 1.92e-01
#
# Epoch 10000 || learning rate 2.50e-04
# Global loss 1.94e-01 || loss ode 6.08e-04 || loss b0 2.54e-05 || loss b1 3.41e-05 || loss data 1.91e-01

# %% [markdown]
# # Visualize the loss function

# %%
epochs = range(n_epochs+1)
#y_lims = [np.min(loss_values)*0.8,np.max(loss_values)*1.2]

fig, axs = plt.subplots(1,2,figsize = (15,7), num =4)
axs[0].semilogy(epochs,loss_values[:,0])
axs[0].set_xlabel('Numeber of Epochs')
#axs[0].set_ylim(y_lims)
axs[0].grid('on')
axs[0].set_title('Global loss')

axs[1].semilogy(epochs,loss_values[:,1],label = 'ODE')
axs[1].semilogy(epochs,loss_values[:,2],label = 'b0' )
axs[1].semilogy(epochs,loss_values[:,3],label = 'b1' )
axs[1].semilogy(epochs,loss_values[:,4],label = 'data' )
axs[1].set_xlabel('Numeber of Epochs')
#axs[1].set_ylim(y_lims)
axs[1].legend()
axs[1].grid('on')
axs[1].set_title('Components loss')

plt.show()

# %% [markdown]
# # Visualize the results

# %%
u_NN_test = convert(FNN(torch.tensor(x_test)))
# Out:
# C:\Users\elena\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\utils\_device.py:103: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return func(*args, **kwargs)

# %%
fig, axs = plt.subplots(1,2,figsize = (15,7))
axs[0].plot(x_test,convert(u_exact_test),label = 'Exact')
axs[0].plot(x_test,u_NN_test, label = 'Test prediction')
axs[0].set_xlabel('x')
axs[0].legend()
axs[0].set_title('Comparision')
axs[0].grid()

axs[1].semilogy(x_test,np.abs(convert(u_exact_test)-u_NN_test))
axs[1].set_title('Point-wise error')
axs[1].set_xlabel('x')
axs[1].set_ylabel('|u - $u_{NN}$|')
plt.show()

# %%
plt.plot(epochs,alpha_values)
plt.plot(epochs,alpha_exact*np.ones(alpha_values.shape))
plt.grid()
