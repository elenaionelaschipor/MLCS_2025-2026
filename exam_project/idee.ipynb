# %% [markdown]
# ## Modified CNN for Parametric PDEs

# %% [markdown]
# devo:
# - capire come ''creare'' il dataset ---- > non è che riesco a usare uno di quelli fatti dal prof nel corso?
#     dubito, siccome devo averli fatti con il multigrid method??
# - iniziare a implementare quello che fa nell'articolo
# - sperare in bene dal pto di vista informatico e poi fare il powerpoint

# %% [markdown]
# <img src = " ./images/text1.png">

# %% [markdown]
# #### creazione dataset:
# me la riesco a cavare usando il data_gen.ipynb che ha fatto il prof per il lab 4, lo devo modificare per la questione che qui faccio un metodo multigrid ma okay

# %% [markdown]
# <img src = " ./images/text2.png">

# %% [markdown]
# dai riferimenti bibliografici, quando ho uniform smooth field ho:

# %% [markdown]
# <img src = " ./images/text3.png">

# %% [markdown]
# <img src = " ./images/text4.png">
