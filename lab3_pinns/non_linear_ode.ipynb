# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import torch.nn as nn
from DNN import DeepNet
torch.set_default_dtype(torch.float64)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.set_default_device(device) # default tensor device
print("I'm using: ", device)
# Out:
# I'm using:  cpu

# %% [markdown]
# ## A non-linear boundary value problem
# We consider the problem
# $$
# \begin{cases}
#     \displaystyle -\frac{d}{dx}\Big[(1+u(x)^2)\frac{d}{dx}u\Big] = -2\pi^2\cos(\pi x)^2\sin(\pi x) +  \pi^2 \sin(\pi x)\big(\sin(\pi x)^2 +1\big) =: f(x), \quad x \in (0,2) \\[15pt]
#     u(0) = u(2) = 0
# \end{cases}
# $$
# Which is solved by $u(x) = \sin(\pi x)$.
#
# We start by introducing some helper functions.

# %%
def convert(x):
  return x.cpu().detach().numpy()

def L2_diff(y, y_pred):
  # return np.linalg.norm(y-convert(y_pred),2)
  
  return np.linalg.norm(y-y_pred,2)

# %% [markdown]
# Define a network `FNN`  with 5 layers, 20 neurons and tanh (https://pytorch.org/docs/stable/generated/torch.nn.Tanh.html#tanh) as the activation function

# %%
FNN = DeepNet(torch.nn.Tanh(), 1, 5*[20], 1)  #ok

# %% [markdown]
# Using `torch.rand`, define the points that will be used for training. For the test points, we use equispaced points that can be defined with `torch.linspace`

# %%
x0 = torch.Tensor([0]).to(device)
x1 = torch.Tensor([2]).to(device)
u_b0 = torch.Tensor([0]).to(device)
u_b1 = torch.Tensor([0]).to(device)

n_train_points = 200
n_test_points  = 500

x_train = torch.rand([n_train_points, 1]) *(x1 - x0) + x0
x_sort_train,_ = torch.sort(x_train,0)
x_test  =  torch.linspace(0,2, n_test_points).unsqueeze(-1)

# %% [markdown]
# Visualize the points

# %%
# %matplotlib inline
plt.figure(figsize=(8, 1))  
plt.scatter(convert(x_train), np.zeros_like(convert(x_train)), color='red', s=50, marker='x', label='Collocation Points')
plt.scatter(convert(x0), np.zeros_like(convert(x0)), color='green', s=50, label='Collocation Points')
plt.scatter(convert(x1), np.zeros_like(convert(x1)), color='green', s=50, label='Collocation Points')
plt.xlabel('x')
plt.yticks([])  
plt.title('Collocation Points')
# Out:
# Text(0.5, 1.0, 'Collocation Points')

# %% [markdown]
# Define the exact solution and right hand side

# %%
def rhs(x):
    return -2 * torch.pi**2 * torch.cos(torch.pi * x)**(2) * torch.sin(torch.pi * x) + torch.pi**2 * torch.sin(torch.pi * x)*(torch.sin(torch.pi*x)**(2)+1) 
    # input a torch tensor, output a torch tensor

def exact_sol(x):
    return np.sin(np.pi * convert(x))
    # input a torch tensor, output a numpy one, using the function convert

# %% [markdown]
# In this case, we define a function that computes the loss from
# - the NN $\Phi$ approximating the solution
# - a vector of points $(x_i)_i$
# - the right hand side function $f$
# - a metric computing the distance between the lhs and the rhs
# The function has to compute the term
# $$
# -\frac{d}{dx}\left((1+\Phi^2)\frac{d}{dx}\Phi\right)
# $$
# on the vector of points $(x_i)_i$.  To compute first and second derivatives use `torch.autograd.grad`. You will have to `create_graph=True` and `retain_graph=True`.
#
# The second function exaluates the error at a point: it should return $(\Phi(x) - y)^2$.

# %%
def eval_loss_ode(Phi, x, rhs, metric):
    x.requires_grad_(True) 
    u_NN = Phi(x_train)
    u_NN_x = torch.autograd.grad(u_NN.sum(), x, create_graph=True, retain_graph=True)[0]
    u_NN_x = (1+u_NN*u_NN) * u_NN_x
    u_NN_xx = torch.autograd.grad(u_NN_x.sum(), x, create_graph=True)[0]
    return metric(-u_NN_xx, rhs(x))

def eval_loss_pt(Phi, x, y):
    return (Phi(x) - y).pow(2).squeeze()

# %% [markdown]
# We train the network, as in the previous case.

# %%
n_epochs = 5000
learning_rate = 1e-3
optimizer = torch.optim.Adam( FNN.parameters(), lr = learning_rate)  ## initialize with the right arguments
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 50, 0.96)

loss_values = np.empty([n_epochs+1,4]); #total,ode, b0,b1
MSE =   torch.nn.MSELoss() ## the same as in the previous notebook

STEP = 100 #save every 100 epochs

assert n_epochs%STEP == 0

err = np.empty([int(n_epochs/STEP)+1,2])
u_animate =  np.empty([int(n_epochs/STEP)+1,n_train_points])
err_animate = np.empty([int(n_epochs/STEP)+1,n_train_points])
k = 0 

rhs_train = rhs(x_train)
u_exact_train = exact_sol(x_train)
rhs_train_sort = rhs(x_sort_train)
u_exact_train_sort = exact_sol(x_sort_train)

rhs_test = rhs(x_test)
u_exact_test = exact_sol(x_test)

for epoch in range(n_epochs+1):
    
    ## compute here the three components of the loss: the residual and the two boundary conditions, 
    ## then sum them up
      loss_ode = eval_loss_ode(FNN, x_train, rhs, MSE) ## complete this line
   
      loss_b0 = eval_loss_pt(FNN, x0, u_b0) ## complete this line
      loss_b1 = eval_loss_pt(FNN, x1, u_b1) ## complete this line
      loss_pt = (loss_b0 + loss_b1)  ## complete this line
      loss = loss_ode + loss_pt # loss totale


      optimizer.zero_grad()

    ## differentiate the loss as in the previous notebook (one line)

    ## one step of optimization (one line)
      loss.backward()
      optimizer.step()
      scheduler.step()

      loss_values[epoch,:] = np.stack([convert(loss),convert(loss_ode),convert(loss_b0),convert(loss_b1)])

      if epoch%STEP == 0:
            lr = np.array(scheduler.get_last_lr())
            u_NN_test =  FNN(x_test)
            err[k,:] = [L2_diff(convert(FNN(x_train)),u_exact_train), L2_diff(convert(u_NN_test),u_exact_test)]
            u_animate[k,:]  = convert(FNN(x_sort_train).squeeze())
            err_animate[k,:]= (np.abs(u_animate[k,:] - (u_exact_train_sort.squeeze())))
            print(f'Epoch {epoch} || learning rate {lr.squeeze():.2e}  || Error  Train {err[k,0]:.2e} || Error Test  {err[k,1]:.2e}''\n'
                  f'Global loss {loss_values[epoch,0]:.2e} || loss ode {loss_values[epoch,1]:.2e} || loss b0 {loss_values[epoch,2]:.2e} || loss b1 {loss_values[epoch,3]:.2e}','\n')
            k+=1
# Out:
# Epoch 0 || learning rate 1.00e-03  || Error  Train 1.05e+01 || Error Test  1.65e+01
# Global loss 1.12e+02 || loss ode 1.12e+02 || loss b0 6.45e-02 || loss b1 4.83e-02
#
# Epoch 100 || learning rate 9.22e-04  || Error  Train 2.14e+01 || Error Test  3.48e+01
# Global loss 5.83e+01 || loss ode 5.30e+01 || loss b0 4.40e+00 || loss b1 8.22e-01
#
# Epoch 200 || learning rate 8.49e-04  || Error  Train 2.35e+01 || Error Test  3.80e+01
# Global loss 1.32e+01 || loss ode 5.13e+00 || loss b0 4.10e+00 || loss b1 3.98e+00
#
# Epoch 300 || learning rate 7.83e-04  || Error  Train 2.09e+01 || Error Test  3.39e+01
# Global loss 1.06e+01 || loss ode 3.84e+00 || loss b0 3.40e+00 || loss b1 3.35e+00
#
# Epoch 400 || learning rate 7.21e-04  || Error  Train 1.33e+01 || Error Test  2.18e+01
# Global loss 4.05e+00 || loss ode 4.03e-01 || loss b0 1.75e+00 || loss b1 1.90e+00
#
# Epoch 500 || learning rate 6.65e-04  || Error  Train 3.97e+00 || Error Test  6.12e+00
# Global loss 4.20e-01 || loss ode 2.50e-01 || loss b0 2.30e-02 || loss b1 1.47e-01
#
# Epoch 600 || learning rate 6.13e-04  || Error  Train 2.06e+00 || Error Test  3.22e+00
# Global loss 1.28e-01 || loss ode 8.25e-02 || loss b0 2.14e-02 || loss b1 2.46e-02
#
# Epoch 700 || learning rate 5.65e-04  || Error  Train 9.68e-01 || Error Test  1.55e+00
# Global loss 3.15e-02 || loss ode 1.60e-02 || loss b0 1.25e-02 || loss b1 2.93e-03
#
# Epoch 800 || learning rate 5.20e-04  || Error  Train 6.39e-01 || Error Test  1.04e+00
# Global loss 1.36e-02 || loss ode 6.02e-03 || loss b0 7.10e-03 || loss b1 4.35e-04
#
# Epoch 900 || learning rate 4.80e-04  || Error  Train 4.84e-01 || Error Test  7.81e-01
# Global loss 7.82e-03 || loss ode 3.99e-03 || loss b0 3.69e-03 || loss b1 1.47e-04
#
# Epoch 1000 || learning rate 4.42e-04  || Error  Train 3.68e-01 || Error Test  5.89e-01
# Global loss 5.16e-03 || loss ode 3.34e-03 || loss b0 1.72e-03 || loss b1 9.33e-05
#
# Epoch 1100 || learning rate 4.07e-04  || Error  Train 2.87e-01 || Error Test  4.55e-01
# Global loss 3.92e-03 || loss ode 3.04e-03 || loss b0 8.11e-04 || loss b1 7.10e-05
#
# Epoch 1200 || learning rate 3.75e-04  || Error  Train 2.34e-01 || Error Test  3.69e-01
# Global loss 3.28e-03 || loss ode 2.79e-03 || loss b0 4.33e-04 || loss b1 5.35e-05
#
# Epoch 1300 || learning rate 3.46e-04  || Error  Train 2.00e-01 || Error Test  3.14e-01
# Global loss 2.87e-03 || loss ode 2.56e-03 || loss b0 2.71e-04 || loss b1 3.84e-05
#
# Epoch 1400 || learning rate 3.19e-04  || Error  Train 1.76e-01 || Error Test  2.76e-01
# Global loss 2.55e-03 || loss ode 2.33e-03 || loss b0 1.93e-04 || loss b1 2.61e-05
#
# Epoch 1500 || learning rate 2.94e-04  || Error  Train 1.58e-01 || Error Test  2.47e-01
# Global loss 2.30e-03 || loss ode 2.13e-03 || loss b0 1.50e-04 || loss b1 1.69e-05
#
# Epoch 1600 || learning rate 2.71e-04  || Error  Train 1.43e-01 || Error Test  2.24e-01
# Global loss 2.09e-03 || loss ode 1.95e-03 || loss b0 1.22e-04 || loss b1 1.03e-05
#
# Epoch 1700 || learning rate 2.50e-04  || Error  Train 1.31e-01 || Error Test  2.05e-01
# Global loss 1.91e-03 || loss ode 1.80e-03 || loss b0 1.03e-04 || loss b1 5.82e-06
#
# Epoch 1800 || learning rate 2.30e-04  || Error  Train 1.20e-01 || Error Test  1.89e-01
# Global loss 1.75e-03 || loss ode 1.66e-03 || loss b0 8.84e-05 || loss b1 2.94e-06
#
# Epoch 1900 || learning rate 2.12e-04  || Error  Train 1.11e-01 || Error Test  1.74e-01
# Global loss 1.62e-03 || loss ode 1.54e-03 || loss b0 7.68e-05 || loss b1 1.22e-06
#
# Epoch 2000 || learning rate 1.95e-04  || Error  Train 1.03e-01 || Error Test  1.61e-01
# Global loss 1.51e-03 || loss ode 1.44e-03 || loss b0 6.72e-05 || loss b1 3.29e-07
#
# Epoch 2100 || learning rate 1.80e-04  || Error  Train 9.56e-02 || Error Test  1.50e-01
# Global loss 1.41e-03 || loss ode 1.35e-03 || loss b0 5.92e-05 || loss b1 1.22e-08
#
# Epoch 2200 || learning rate 1.66e-04  || Error  Train 8.90e-02 || Error Test  1.40e-01
# Global loss 1.32e-03 || loss ode 1.27e-03 || loss b0 5.25e-05 || loss b1 8.58e-08
#
# Epoch 2300 || learning rate 1.53e-04  || Error  Train 8.31e-02 || Error Test  1.30e-01
# Global loss 1.24e-03 || loss ode 1.19e-03 || loss b0 4.67e-05 || loss b1 4.16e-07
#
# Epoch 2400 || learning rate 1.41e-04  || Error  Train 7.77e-02 || Error Test  1.22e-01
# Global loss 1.17e-03 || loss ode 1.13e-03 || loss b0 4.17e-05 || loss b1 9.06e-07
#
# Epoch 2500 || learning rate 1.30e-04  || Error  Train 7.28e-02 || Error Test  1.14e-01
# Global loss 1.11e-03 || loss ode 1.07e-03 || loss b0 3.74e-05 || loss b1 1.49e-06
#
# Epoch 2600 || learning rate 1.20e-04  || Error  Train 6.84e-02 || Error Test  1.07e-01
# Global loss 1.06e-03 || loss ode 1.02e-03 || loss b0 3.36e-05 || loss b1 2.11e-06
#
# Epoch 2700 || learning rate 1.10e-04  || Error  Train 6.44e-02 || Error Test  1.01e-01
# Global loss 1.01e-03 || loss ode 9.74e-04 || loss b0 3.03e-05 || loss b1 2.75e-06
#
# Epoch 2800 || learning rate 1.02e-04  || Error  Train 6.08e-02 || Error Test  9.55e-02
# Global loss 9.63e-04 || loss ode 9.32e-04 || loss b0 2.75e-05 || loss b1 3.38e-06
#
# Epoch 2900 || learning rate 9.37e-05  || Error  Train 5.74e-02 || Error Test  9.03e-02
# Global loss 9.23e-04 || loss ode 8.94e-04 || loss b0 2.49e-05 || loss b1 3.98e-06
#
# Epoch 3000 || learning rate 8.64e-05  || Error  Train 5.44e-02 || Error Test  8.55e-02
# Global loss 8.86e-04 || loss ode 8.59e-04 || loss b0 2.27e-05 || loss b1 4.54e-06
#
# Epoch 3100 || learning rate 7.96e-05  || Error  Train 5.15e-02 || Error Test  8.11e-02
# Global loss 8.53e-04 || loss ode 8.27e-04 || loss b0 2.07e-05 || loss b1 5.07e-06
#
# Epoch 3200 || learning rate 7.33e-05  || Error  Train 4.90e-02 || Error Test  7.71e-02
# Global loss 8.23e-04 || loss ode 7.98e-04 || loss b0 1.90e-05 || loss b1 5.55e-06
#
# Epoch 3300 || learning rate 6.76e-05  || Error  Train 4.66e-02 || Error Test  7.34e-02
# Global loss 7.95e-04 || loss ode 7.72e-04 || loss b0 1.74e-05 || loss b1 6.00e-06
#
# Epoch 3400 || learning rate 6.23e-05  || Error  Train 4.44e-02 || Error Test  7.00e-02
# Global loss 7.70e-04 || loss ode 7.47e-04 || loss b0 1.60e-05 || loss b1 6.40e-06
#
# Epoch 3500 || learning rate 5.74e-05  || Error  Train 4.24e-02 || Error Test  6.68e-02
# Global loss 7.46e-04 || loss ode 7.25e-04 || loss b0 1.47e-05 || loss b1 6.75e-06
#
# Epoch 3600 || learning rate 5.29e-05  || Error  Train 4.05e-02 || Error Test  6.39e-02
# Global loss 7.25e-04 || loss ode 7.04e-04 || loss b0 1.36e-05 || loss b1 7.08e-06
#
# Epoch 3700 || learning rate 4.88e-05  || Error  Train 3.88e-02 || Error Test  6.12e-02
# Global loss 7.05e-04 || loss ode 6.85e-04 || loss b0 1.26e-05 || loss b1 7.36e-06
#
# Epoch 3800 || learning rate 4.49e-05  || Error  Train 3.72e-02 || Error Test  5.87e-02
# Global loss 6.86e-04 || loss ode 6.67e-04 || loss b0 1.17e-05 || loss b1 7.62e-06
#
# Epoch 3900 || learning rate 4.14e-05  || Error  Train 3.57e-02 || Error Test  5.64e-02
# Global loss 6.69e-04 || loss ode 6.51e-04 || loss b0 1.09e-05 || loss b1 7.84e-06
#
# Epoch 4000 || learning rate 3.82e-05  || Error  Train 3.44e-02 || Error Test  5.42e-02
# Global loss 6.53e-04 || loss ode 6.35e-04 || loss b0 1.01e-05 || loss b1 8.04e-06
#
# Epoch 4100 || learning rate 3.52e-05  || Error  Train 3.31e-02 || Error Test  5.22e-02
# Global loss 6.39e-04 || loss ode 6.21e-04 || loss b0 9.44e-06 || loss b1 8.21e-06
#
# Epoch 4200 || learning rate 3.24e-05  || Error  Train 3.19e-02 || Error Test  5.03e-02
# Global loss 6.25e-04 || loss ode 6.08e-04 || loss b0 8.82e-06 || loss b1 8.36e-06
#
# Epoch 4300 || learning rate 2.99e-05  || Error  Train 3.08e-02 || Error Test  4.86e-02
# Global loss 6.12e-04 || loss ode 5.95e-04 || loss b0 8.26e-06 || loss b1 8.48e-06
#
# Epoch 4400 || learning rate 2.75e-05  || Error  Train 2.98e-02 || Error Test  4.70e-02
# Global loss 6.00e-04 || loss ode 5.83e-04 || loss b0 7.75e-06 || loss b1 8.59e-06
#
# Epoch 4500 || learning rate 2.54e-05  || Error  Train 2.88e-02 || Error Test  4.54e-02
# Global loss 5.88e-04 || loss ode 5.72e-04 || loss b0 7.28e-06 || loss b1 8.69e-06
#
# Epoch 4600 || learning rate 2.34e-05  || Error  Train 2.79e-02 || Error Test  4.40e-02
# Global loss 5.78e-04 || loss ode 5.62e-04 || loss b0 6.86e-06 || loss b1 8.77e-06
#
# Epoch 4700 || learning rate 2.16e-05  || Error  Train 2.70e-02 || Error Test  4.27e-02
# Global loss 5.68e-04 || loss ode 5.53e-04 || loss b0 6.46e-06 || loss b1 8.83e-06
#
# Epoch 4800 || learning rate 1.99e-05  || Error  Train 2.63e-02 || Error Test  4.14e-02
# Global loss 5.58e-04 || loss ode 5.43e-04 || loss b0 6.10e-06 || loss b1 8.89e-06
#
# Epoch 4900 || learning rate 1.83e-05  || Error  Train 2.55e-02 || Error Test  4.03e-02
# Global loss 5.50e-04 || loss ode 5.35e-04 || loss b0 5.77e-06 || loss b1 8.93e-06
#
# Epoch 5000 || learning rate 1.69e-05  || Error  Train 2.48e-02 || Error Test  3.92e-02
# Global loss 5.41e-04 || loss ode 5.27e-04 || loss b0 5.47e-06 || loss b1 8.96e-06

# %% [markdown]
# # Visualization of the results
# Value of the loss function at the vary of the epochs

# %%
epochs = range(n_epochs+1)
#y_lims = [np.min(loss_values)*0.8,np.max(loss_values)*1.2]

fig, axs = plt.subplots(1,2,figsize = (15,7), num =4)
axs[0].semilogy(epochs,loss_values[:,0])
axs[0].set_xlabel('Numeber of Epochs')
#axs[0].set_ylim(y_lims)
axs[0].grid('on')
axs[0].set_title('Global loss')

axs[1].semilogy(epochs,loss_values[:,1],label = 'ODE')
axs[1].semilogy(epochs,loss_values[:,2],label = 'b0' )
axs[1].semilogy(epochs,loss_values[:,3],label = 'b1' )
axs[1].set_xlabel('Numeber of Epochs')
#axs[1].set_ylim(y_lims)
axs[1].legend()
axs[1].grid('on')
axs[1].set_title('Components loss')

plt.show()

# %%
x_test_converted = convert(x_test)
u_NN_test_converted = convert(FNN(x_test))
x_sort_train_converted = convert(x_sort_train)

# %% [markdown]
# Compare the exact solution with the PINN prediction and evaluate the point-wise error

# %%
# x_test = convert(x_test)
# u_NN_test = convert(u_NN_test)
# x_sort_train = convert(x_sort_train)

# %%
fig, axs = plt.subplots(1,2,figsize = (15,7))
axs[0].plot(x_test_converted,u_exact_test,label = 'Exact')
axs[0].plot(x_test_converted,u_NN_test_converted, label = 'Test prediction')
axs[0].set_xlabel('x')
axs[0].legend()
axs[0].set_title('Comparision')

axs[1].semilogy(x_test_converted,np.abs(u_exact_test-u_NN_test_converted))
axs[1].set_title('Point-wise error')
axs[1].set_xlabel('x')
axs[1].set_ylabel('|u - $u_{NN}$|')
plt.show()

# %% [markdown]
# $L^2$ Errors

# %%
epochs = range(n_epochs+1)
y_lims = [np.min(loss_values)*0.8,np.max(loss_values)*1.2]

plt.semilogy(epochs,loss_values[:,0],label = 'values of the loss')
plt.semilogy(epochs[0:-1:STEP-1],err[:,0],'-x', label = '$L^2$ Training error')
plt.semilogy(epochs[0:-1:STEP-1],err[:,1],'-x', label = '$L^2$ Test error')

plt.xlabel('Number of epochs')
plt.grid('on')
plt.legend()
plt.show()

# %% [markdown]
# Animation of the solution and of the point wise error during training

# %%
#matplotlib widget
fig, axs = plt.subplots(1,2, figsize = (15,7),num = 3)

def updata_data(frame):
    axs[0].clear()
    axs[0].plot(x_sort_train,u_animate[frame,:],'b--',label = r'$y_{\Theta}$')
    axs[0].plot(x_sort_train,u_exact_train_sort,'r', label = 'Exact')
    axs[0].set_ylim([-np.max(u_animate),np.max(u_animate)])
    axs[0].set_xlim([0,2])
    axs[0].set_xlabel('t')

    axs[0].grid('on')
    axs[0].legend()

    axs[1].clear()
    axs[1].semilogy(x_sort_train,err_animate[frame,:])
    axs[1].grid('on')
    axs[1].set_ylim([np.min(err_animate)*0.9,np.max(err_animate)*1.1])
    axs[1].set_xlabel('t')
    axs[1].set_title(r'$|y - y_{\Theta}|$')
    plt.suptitle(f'Epoch {frame*STEP} || error {err[frame,0]:.2e}')
    return axs[0]

animation = FuncAnimation(fig,func = updata_data,frames=len(u_animate),interval = 500,)
# plt.show()
# for google colab
from IPython.display import HTML
video = HTML(animation.to_html5_video())
display(video)
plt.close()
# Out:
# <video width="1500" height="700" controls autoplay loop>
#   <source type="video/mp4" src="...
