# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import torch.nn as nn
from DNN import DeepNet
torch.set_default_dtype(torch.float64)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.set_default_device(device) # default tensor device
print("I'm using: ", device)
# Out:
# I'm using:  cpu

# %% [markdown]
# ## A non-linear boundary value problem
# We consider the problem
# $$
# \begin{cases}
#     \displaystyle -\frac{d}{dx}\Big[(1+u(x)^2)\frac{d}{dx}u\Big] = -2\pi^2\cos(\pi x)^2\sin(\pi x) +  \pi^2 \sin(\pi x)\big(\sin(\pi x)^2 +1\big) =: f(x), \quad x \in (0,2) \\[15pt]
#     u(0) = u(2) = 0
# \end{cases}
# $$
# Which is solved by $u(x) = \sin(\pi x)$.
#
# We start by introducing some helper functions.

# %%
def convert(x):
  return x.cpu().detach().numpy()

def L2_diff(y, y_pred):
  return np.linalg.norm(y-convert(y_pred),2)

# %% [markdown]
# Define a network `FNN`  with 5 layers, 20 neurons and tanh (https://pytorch.org/docs/stable/generated/torch.nn.Tanh.html#tanh) as the activation function

# %%
FNN = DeepNet(torch.nn.Tanh(), 1, 5*[20], 1)  #ok

# %% [markdown]
# Using `torch.rand`, define the points that will be used for training. For the test points, we use equispaced points that can be defined with `torch.linspace`

# %%
x0 = torch.Tensor([0]).to(device)
x1 = torch.Tensor([2]).to(device)
u_b0 = torch.Tensor([0]).to(device)
u_b1 = torch.Tensor([0]).to(device)

n_train_points = 50
n_test_points  = 100

x_train = torch.rand(n_train_points, 1) *(x1 - x0) + x0
x_sort_train,_ = torch.sort(x_train,0)
x_test  =  torch.linspace(0,1, n_test_points).unsqueeze(-1) *(x1 - x0) + x0
x_sort_test,_ = torch.sort(x_test,0)

# %% [markdown]
# Visualize the points

# %%
# %matplotlib inline
plt.figure(figsize=(8, 1))  
plt.scatter(convert(x_train), np.zeros_like(convert(x_train)), color='red', s=50, marker='x', label='Collocation Points')
plt.scatter(convert(x0), np.zeros_like(convert(x0)), color='green', s=50, label='Collocation Points')
plt.scatter(convert(x1), np.zeros_like(convert(x1)), color='green', s=50, label='Collocation Points')
plt.xlabel('x')
plt.yticks([])  
plt.title('Collocation Points')
# Out:
# Text(0.5, 1.0, 'Collocation Points')

# %% [markdown]
# Define the exact solution and right hand side

# %%
def rhs(x):
    return -2 * np.pi**2 * torch.cos(np.pi * x).pow(2) * torch.sin(np.pi * x) + np.pi**2 * torch.sin(np.pi * x)*(torch.sin(np.pi*x).pow(2)+1) 
    # input a torch tensor, output a torch tensor

def exact_sol(x):
    return torch.sin(np.pi * x)
    # input a torch tensor, output a numpy one, using the function convert

# %% [markdown]
# In this case, we define a function that computes the loss from
# - the NN $\Phi$ approximating the solution
# - a vector of points $(x_i)_i$
# - the right hand side function $f$
# - a metric computing the distance between the lhs and the rhs
# The function has to compute the term
# $$
# -\frac{d}{dx}\left((1+\Phi^2)\frac{d}{dx}\Phi\right)
# $$
# on the vector of points $(x_i)_i$.  To compute first and second derivatives use `torch.autograd.grad`. You will have to `create_graph=True` and `retain_graph=True`.
#
# The second function exaluates the error at a point: it should return $(\Phi(x) - y)^2$.

# %%
def mymetric(y_pred, y):
    return -torch.autograd.grad((1+y_pred**2)*torch.autograd.grad(y_pred, x_train, torch.ones_like(y_pred), create_graph=True)[0], x_train, torch.ones_like(y_pred), create_graph=True)[0] - rhs(x_train)

# %%
def eval_loss_ode(Phi, x, rhs, metric):
    x.requires_grad_(True) 
    phi_prime = torch.autograd.grad(Phi(x).sum(), x, create_graph = True)[0]
    return metric(phi_prime, rhs(x))
    ## complete the function

def eval_loss_pt(Phi, x, y):
    return (Phi(x) - y).pow(2).squeeze()
    ## complete the function

# %% [markdown]
# We train the network, as in the previous case.

# %%
print(FNN(x_train).shape, u_exact_train.shape,x_test.shape, FNN(x_test).shape, u_exact_test.shape, u_NN_test.shape)
# Out:
# torch.Size([50, 1]) torch.Size([50, 1]) torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1])

# %%
n_epochs = 5000
learning_rate = 1e-3
optimizer = torch.optim.Adam( FNN.parameters(), lr = learning_rate)  ## initialize with the right arguments
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 50, 0.96)

loss_values = np.empty([n_epochs+1,4]); #total,ode, b0,b1
MSE =   torch.nn.MSELoss() ## the same as in the previous notebook

STEP = 100 #save every 100 epochs

assert n_epochs%STEP == 0

err = np.empty([int(n_epochs/STEP)+1,2])
u_animate =  np.empty([int(n_epochs/STEP)+1,n_train_points])
err_animate = np.empty([int(n_epochs/STEP)+1,n_train_points])
k = 0 

rhs_train = rhs(x_train)
u_exact_train = exact_sol(x_train)
rhs_train_sort = rhs(x_sort_train)
u_exact_train_sort = exact_sol(x_sort_train)

rhs_test = rhs(x_test)
u_exact_test = exact_sol(x_test)

for epoch in range(n_epochs+1):
    
    ## compute here the three components of the loss: the residual and the two boundary conditions, 
    ## then sum them up
      loss_ode = eval_loss_ode(FNN, x_train, rhs, mymetric) ## complete this line
   
      loss_b0 = eval_loss_pt(FNN, x0, 0) ## complete this line
      loss_b1 = eval_loss_pt(FNN, x1, 0) ## complete this line
      loss_pt = (loss_b0 + loss_b1)  ## complete this line
      loss = loss_ode + loss_pt # loss totale


      optimizer.zero_grad()

    ## differentiate the loss as in the previous notebook (one line)

    ## one step of optimization (one line)
      loss.backward()
      optimizer.step()
      scheduler.step()

      loss_values[epoch,:] = np.stack([convert(loss),convert(loss_ode),convert(loss_b0),convert(loss_b1)])

      if epoch%STEP == 0:
            lr = np.array(scheduler.get_last_lr())
            u_NN_test =  FNN(x_test)
            err[k,:] = [L2_diff(convert(FNN(x_train)),u_exact_train), L2_diff(convert(u_NN_test),u_exact_test)]
            u_animate[k,:]  = convert(FNN(x_sort_train).squeeze())
            err_animate[k,:]= (np.abs(u_animate[k,:] - convert(u_exact_train_sort.squeeze())))
            print(f'Epoch {epoch} || learning rate {lr.squeeze():.2e}  || Error  Train {err[k,0]:.2e} || Error Test  {err[k,1]:.2e}''\n'
                  f'Global loss {loss_values[epoch,0]:.2e} || loss ode {loss_values[epoch,1]:.2e} || loss b0 {loss_values[epoch,2]:.2e} || loss b1 {loss_values[epoch,3]:.2e}','\n')
            k+=1
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[114], line 43
#      38   optimizer.zero_grad()
#      40 ## differentiate the loss as in the previous notebook (one line)
#      41
#      42 ## one step of optimization (one line)
# ---> 43   loss.backward()
#      44   optimizer.step()
#      45   scheduler.step()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\_tensor.py:638, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     595 r"""Computes the gradient of current tensor wrt graph leaves.
#     596
#     597 The graph is differentiated using the chain rule. If the tensor is
#    (...)    635         used to compute the :attr:`tensors`. Defaults to ``None``.
#     636 """
#     637 if has_torch_function_unary(self):
# --> 638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#     641         self,
#     642         gradient=gradient,
#     643         retain_graph=retain_graph,
#     644         create_graph=create_graph,
#     645         inputs=inputs,
#     646     )
#     647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\overrides.py:1725, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1721 if _is_torch_function_mode_enabled():
#    1722     # if we're here, the mode must be set to a TorchFunctionStackMode
#    1723     # this unsets it and calls directly into TorchFunctionStackMode's torch function
#    1724     with _pop_mode_temporarily() as mode:
# -> 1725         result = mode.__torch_function__(public_api, types, args, kwargs)
#    1726     if result is not NotImplemented:
#    1727         return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\utils\_device.py:103, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     101 if func in _device_constructors() and kwargs.get("device") is None:
#     102     kwargs["device"] = self.device
# --> 103 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)    645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     344     tensors = tuple(tensors)
#     346 grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 347 grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     348 if retain_graph is None:
#     349     retain_graph = create_graph
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\autograd\__init__.py:199, in _make_grads(outputs, grads, is_grads_batched)
#     197     out_numel_is_1 = out.numel() == 1
#     198 if not out_numel_is_1:
# --> 199     raise RuntimeError(
#     200         "grad can be implicitly created only for scalar outputs"
#     201     )
#     202 if not out_dtype.is_floating_point:
#     203     msg = (
#     204         "grad can be implicitly created only for real scalar outputs"
#     205         f" but got {out_dtype}"
#     206     )
#
# RuntimeError: grad can be implicitly created only for scalar outputs

# %% [markdown]
# # Visualization of the results
# Value of the loss function at the vary of the epochs

# %%
epochs = range(n_epochs+1)
#y_lims = [np.min(loss_values)*0.8,np.max(loss_values)*1.2]

fig, axs = plt.subplots(1,2,figsize = (15,7), num =4)
axs[0].semilogy(epochs,loss_values[:,0])
axs[0].set_xlabel('Numeber of Epochs')
#axs[0].set_ylim(y_lims)
axs[0].grid('on')
axs[0].set_title('Global loss')

axs[1].semilogy(epochs,loss_values[:,1],label = 'ODE')
axs[1].semilogy(epochs,loss_values[:,2],label = 'b0' )
axs[1].semilogy(epochs,loss_values[:,3],label = 'b1' )
axs[1].set_xlabel('Numeber of Epochs')
#axs[1].set_ylim(y_lims)
axs[1].legend()
axs[1].grid('on')
axs[1].set_title('Components loss')

plt.show()

# %%
x_test_converted = convert(x_test)
u_NN_test_converted = convert(FNN(x_test))
x_sort_train_converted = convert(x_sort_train)

# %% [markdown]
# Compare the exact solution with the PINN prediction and evaluate the point-wise error

# %%
# x_test = convert(x_test)
# u_NN_test = convert(u_NN_test)
# x_sort_train = convert(x_sort_train)

# %%
fig, axs = plt.subplots(1,2,figsize = (15,7))
axs[0].plot(x_test_converted,u_exact_test,label = 'Exact')
axs[0].plot(x_test_converted,u_NN_test_converted, label = 'Test prediction')
axs[0].set_xlabel('x')
axs[0].legend()
axs[0].set_title('Comparision')

axs[1].semilogy(x_test_converted,np.abs(u_exact_test-u_NN_test_converted))
axs[1].set_title('Point-wise error')
axs[1].set_xlabel('x')
axs[1].set_ylabel('|u - $u_{NN}$|')
plt.show()
# Out:
# C:\Users\elena\AppData\Local\Temp\ipykernel_18016\3034535800.py:8: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   axs[1].semilogy(x_test_converted,np.abs(u_exact_test-u_NN_test_converted))

# %% [markdown]
# $L^2$ Errors

# %%
epochs = range(n_epochs+1)
y_lims = [np.min(loss_values)*0.8,np.max(loss_values)*1.2]

plt.semilogy(epochs,loss_values[:,0],label = 'values of the loss')
plt.semilogy(epochs[0:-1:STEP-1],err[:,0],'-x', label = '$L^2$ Training error')
plt.semilogy(epochs[0:-1:STEP-1],err[:,1],'-x', label = '$L^2$ Test error')

plt.xlabel('Number of epochs')
plt.grid('on')
plt.legend()
plt.show()

# %% [markdown]
# Animation of the solution and of the point wise error during training

# %%
#matplotlib widget
fig, axs = plt.subplots(1,2, figsize = (15,7),num = 3)

def updata_data(frame):
    axs[0].clear()
    axs[0].plot(x_sort_train,u_animate[frame,:],'b--',label = r'$y_{\Theta}$')
    axs[0].plot(x_sort_train,u_exact_train_sort,'r', label = 'Exact')
    axs[0].set_ylim([-np.max(u_animate),np.max(u_animate)])
    axs[0].set_xlim([0,2])
    axs[0].set_xlabel('t')

    axs[0].grid('on')
    axs[0].legend()

    axs[1].clear()
    axs[1].semilogy(x_sort_train,err_animate[frame,:])
    axs[1].grid('on')
    axs[1].set_ylim([np.min(err_animate)*0.9,np.max(err_animate)*1.1])
    axs[1].set_xlabel('t')
    axs[1].set_title(r'$|y - y_{\Theta}|$')
    plt.suptitle(f'Epoch {frame*STEP} || error {err[frame,0]:.2e}')
    return axs[0]

animation = FuncAnimation(fig,func = updata_data,frames=len(u_animate),interval = 500,)
# plt.show()
# for google colab
from IPython.display import HTML
video = HTML(animation.to_html5_video())
display(video)
plt.close()
# Out:
# <video width="1500" height="700" controls autoplay loop>
#   <source type="video/mp4" src="...
