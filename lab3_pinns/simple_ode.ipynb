# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import torch.nn as nn
from DNN import DeepNet
torch.set_default_dtype(torch.float64)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.set_default_device(device) # default tensor device
print("I'm using: ", device)
# Out:
# I'm using:  cpu

# %%
def convert(x):
  return x.cpu().detach().numpy()

def L2_diff(y,y_pred):
  return np.linalg.norm(y-y_pred,2)

# %% [markdown]
# ## A simple ODE
# We consider the problem
# $$
# \begin{cases}
#     \displaystyle \frac{dy(t)}{dt} =  - 2y(t) =: f(t, y(t)) ,\ \ t\in (0,1)\\[15pt]
#     y(0) = 1 =: y_0 .
# \end{cases}
# $$
# That we want to approximate with a PINN. This means that we want to replace the solution $y(t)$ by a neural network $\Phi$, then optimize the parameters of the network to minimize the loss function
# $$
# \mathcal{L}(\Phi) := \sum_{i=1}^N \mathrm{dist}(\Phi'(t_i), f(t_i, \Phi(t_i))) + (\Phi(0)-y_0)^2,
# $$
# where $t_1, \dots, t_N$ are points in $(0,1)$ and for some distance $\mathrm{dist}$ that we will choose later.

# %% [markdown]
# Define a network `FNN`$:\mathbb{R}\to\mathbb{R}$ with 3 layers, 5 neurons and `tanh` (see https://pytorch.org/docs/stable/generated/torch.nn.Tanh.html#tanh) as the activation function. Use the `DeepNet` class from the first lab, provided in the `DNN` module that we have imported.

# %%
FNN = DeepNet(torch.nn.Tanh(), 1, [5,5,5], 1)  #ok

# %%
FNN
# Out:
# DeepNet(
#   (activation): Tanh()
#   (hidden): ModuleList(
#     (0): Linear(in_features=1, out_features=5, bias=True)
#     (1-2): 2 x Linear(in_features=5, out_features=5, bias=True)
#   )
#   (output): Linear(in_features=5, out_features=1, bias=False)
# )

# %% [markdown]
# Using `torch.rand`, define the points that will be used for training (i.e., where the residuals will be computed). For the points used for testing, use `torch.linspace`. We use $50$ points for training, and test on $100$ points.

# %%
#ok

t0 = torch.Tensor([0]).to(device)
y0 = torch.Tensor([1]).to(device)  

n_train_points = 50 # it's already scaled between 0 and 1  
n_test_points  = 100 

t_train= torch.rand(n_train_points, 1) # we want a (n_train_points x 1) vector here
t_sort_train, _ = torch.sort(t_train,0) 
t_test =  torch.linspace(0,1, n_test_points).unsqueeze(-1) # dimensions: n_test_points x 1

# %%
t_test.shape
# Out:
# torch.Size([100, 1])

# %% [markdown]
# Visualize the points

# %%
plt.figure(figsize=(8, 1),num =1)  
plt.scatter(convert(t_train), np.zeros_like(convert(t_train)), color='red', s=50, marker='x', label='Collocation Points')
plt.scatter(convert(t0), np.zeros_like(convert(t0)), color='green', s=50, label='Collocation Points')
plt.xlabel('x')
plt.yticks([])  
plt.title('Collocation Points')
# Out:
# Text(0.5, 1.0, 'Collocation Points')

# %% [markdown]
# We define the exact solution and the right hand side function $f(t, y)$

# %%
def exact_sol(t):
    ## takes a torch vector as input, returs a numpy vector (use the `convert` function)
    return np.exp(-2*convert(t))


def rhs(t, y):
    ## input: torch, output: torch
    return -2*y

# %% [markdown]
# Definition of the loss function for the training, where the metric will be defined later. Some examples can be https://pytorch.org/docs/stable/nn.html#loss-functions.
#
# Let $\Phi$ be the neural network approximating $y$. The first function takes $\Phi$, a vector of points $\mathbf{t} = (t_i)_i$, the right hand side function $f:\mathbb{R}\times\mathbb{R}\to\mathbb{R}$, and finally a function `metric`$:\mathbb{R}^N\times \mathbb{R}^N\to \mathbb{R}_+$ which computes some distance between the vectors.
#
# The function then computes $\Phi(\mathbf{t})$ and $\Phi'(\mathbf{t})$ and finally it returns
# $$
# \mathtt{metric}(\Phi'(\mathbf{t}), f(\mathbf{t}, \Phi(\mathbf{t})))
# $$
#
# The second function computes the (squared) error in the inital condition, i.e., $(\Phi(0) - y_0)^2$: it takes as arguments $\Phi$, the initial point $t_0$ and the exact value $y_0$.

# %%
t_train.requires_grad_(True)
torch.autograd.grad(sum(FNN(t_train)), t_train)
# Out:
# (tensor([[0.0316],
#          [0.0331],
#          [0.0357],
#          [0.0388],
#          [0.0299],
#          [0.0336],
#          [0.0392],
#          [0.0379],
#          [0.0392],
#          [0.0343],
#          [0.0283],
#          [0.0383],
#          [0.0367],
#          [0.0391],
#          [0.0390],
#          [0.0392],
#          [0.0389],
#          [0.0379],
#          [0.0293],
#          [0.0386],
#          [0.0392],
#          [0.0377],
#          [0.0391],
#          [0.0356],
#          [0.0308],
#          [0.0390],
#          [0.0354],
#          [0.0318],
#          [0.0316],
#          [0.0387],
#          [0.0334],
#          [0.0336],
#          [0.0305],
#          [0.0356],
#          [0.0345],
#          [0.0391],
#          [0.0387],
#          [0.0304],
#          [0.0312],
#          [0.0318],
#          [0.0357],
#          [0.0311],
#          [0.0341],
#          [0.0388],
#          [0.0350],
#          [0.0319],
#          [0.0392],
#          [0.0282],
#          [0.0392],
#          [0.0332]]),)

# %%
def eval_loss_ode(NN, t, f, metric):
    t.requires_grad_(True)
    phi_prime = torch.autograd.grad(NN(t).sum(), t, create_graph = True, retain_graph=True)[0]
    # print(phi_prime)
    # sommo perchè tanto facendo la derivata non cambia nulla ma è più semplice da gestire
    return torch.tensor([[metric(phi_prime, f(t, NN(t)))]])  # lui non mette il torch tensor 1x1, vediamo

def eval_loss_IC(NN, t_0, y_0):
    return (NN(t_0) - y_0).pow(2)

# %% [markdown]
# Training of the network: see https://pytorch.org/docs/stable/optim.html for an overview. We start by defining the total number of iteration steps, and initialize the Adam optimizer and learning rate scheduler. Finally, we choose the `metric` function to compute the residuals. We want to use the mean squared error, see https://pytorch.org/docs/stable/generated/torch.nn.MSELoss.html

# %%
FNN.parameters()
# Out:
# <generator object Module.parameters at 0x000001B7B27A19A0>

# %%
n_epochs = 2000
learning_rate = 1e-3

optimizer = torch.optim.Adam( FNN.parameters(), lr = learning_rate) ## put the right arguments in
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 50, 0.98)
loss_values = np.empty([n_epochs+1, 3]); #total, ode, 0

## this is the `metric` function that we will use
MSE =  torch.nn.MSELoss()

# %% [markdown]
# We then set the variables for saving the results and initialize the values of the exact solution on the training and test point sets.

# %%
STEP = 200  # save every STEP epochs
assert n_epochs%STEP == 0

err = np.empty([int(n_epochs/STEP)+1, 2])
y_animate =  np.empty([int(n_epochs/STEP)+1, n_train_points])
err_animate = np.empty([int(n_epochs/STEP)+1, n_train_points])
k = 0 

y_exact_train = exact_sol(t_train)
y_exact_test  = exact_sol(t_test)
y_exact_train_sort = exact_sol(t_sort_train)

# %% [markdown]
# We now start iterating on the optimization procedure

# %%
err.shape
# Out:
# (11, 2)

# %%
for epoch in range(n_epochs+1):
    
    loss_ode = eval_loss_ode(FNN, t_train, rhs, MSE) ## complete this line
   
    loss_IC = eval_loss_IC(FNN, t0, y0) ## complete this line

    loss = loss_ode + loss_IC # loss totale

    optimizer.zero_grad()       # backpropagation step: zero the gradient buffers of all parameters

    ## differentiate the loss function (see: https://pytorch.org/docs/stable/generated/torch.Tensor.backward.html )
    ## (one line)
    
    #!!!!!!!!!!!!!!!!
        # questo pezzo è importante ed è importante che le robe siano nello stesso ordine   
    loss.backward() # backpropagation rispetto ai parametri della rete

    ## make one optimization step (one line, see https://pytorch.org/docs/stable/generated/torch.optim.Optimizer.step.html)
    optimizer.step()   # ottimizzo
    scheduler.step()    # cambio passo
 
    #!!!!!!!!!!!!!!!!!

    loss_values[epoch,:] = np.stack([convert(loss),convert(loss_ode),convert(loss_IC)]).squeeze()

    if epoch%STEP == 0:
        lr = np.array(scheduler.get_last_lr())
        y_NN_test =  FNN(t_test)
        err[k,:]  = [L2_diff(convert(FNN(t_train)),y_exact_train), L2_diff(convert(y_NN_test), y_exact_test)]
        y_animate[k,:]  = convert(FNN(t_sort_train).squeeze())
        err_animate[k,:]= (np.abs(y_animate[k,:] - y_exact_train_sort.squeeze()))
        print(f'Epoch {epoch} || learning rate {lr.squeeze():.2e}  || Error  Train {err[k,0]:.2e} || Error Test  {err[k,1]:.2e}''\n'
              f'Global loss {loss_values[epoch,0]:.2e} || loss ode {loss_values[epoch,1]:.2e} || loss IC {loss_values[epoch,2]:.2e}','\n')
        k+=1
# Out:
# tensor([[0.3589]])
# Epoch 0 || learning rate 1.00e-03  || Error  Train 5.59e+00 || Error Test  7.87e+00
# Global loss 2.14e+00 || loss ode 3.59e-01 || loss IC 1.78e+00
#
# tensor([[0.3454]])
# tensor([[0.3321]])
# tensor([[0.3191]])
# tensor([[0.3063]])
# tensor([[0.2937]])
# tensor([[0.2814]])
# tensor([[0.2693]])
# tensor([[0.2574]])
# tensor([[0.2457]])
# tensor([[0.2343]])
# tensor([[0.2232]])
# tensor([[0.2122]])
# tensor([[0.2016]])
# tensor([[0.1911]])
# tensor([[0.1810]])
# tensor([[0.1710]])
# tensor([[0.1614]])
# tensor([[0.1520]])
# tensor([[0.1428]])
# tensor([[0.1339]])
# tensor([[0.1253]])
# tensor([[0.1170]])
# tensor([[0.1089]])
# tensor([[0.1011]])
# tensor([[0.0936]])
# tensor([[0.0863]])
# tensor([[0.0793]])
# tensor([[0.0727]])
# tensor([[0.0662]])
# tensor([[0.0601]])
# tensor([[0.0543]])
# tensor([[0.0487]])
# tensor([[0.0435]])
# tensor([[0.0385]])
# tensor([[0.0338]])
# tensor([[0.0294]])
# tensor([[0.0254]])
# tensor([[0.0216]])
# tensor([[0.0181]])
# tensor([[0.0150]])
# tensor([[0.0121]])
# tensor([[0.0095]])
# tensor([[0.0073]])
# tensor([[0.0054]])
# tensor([[0.0038]])
# tensor([[0.0025]])
# tensor([[0.0015]])
# tensor([[0.0008]])
# tensor([[0.0005]])
# tensor([[0.0005]])
# tensor([[0.0008]])
# tensor([[0.0014]])
# tensor([[0.0023]])
# tensor([[0.0035]])
# tensor([[0.0050]])
# tensor([[0.0069]])
# tensor([[0.0091]])
# tensor([[0.0115]])
# tensor([[0.0143]])
# tensor([[0.0174]])
# tensor([[0.0208]])
# tensor([[0.0246]])
# tensor([[0.0286]])
# tensor([[0.0330]])
# tensor([[0.0377]])
# tensor([[0.0426]])
# tensor([[0.0479]])
# tensor([[0.0536]])
# tensor([[0.0595]])
# tensor([[0.0657]])
# tensor([[0.0723]])
# tensor([[0.0791]])
# tensor([[0.0863]])
# tensor([[0.0938]])
# tensor([[0.1015]])
# tensor([[0.1096]])
# tensor([[0.1180]])
# tensor([[0.1267]])
# tensor([[0.1357]])
# tensor([[0.1450]])
# tensor([[0.1546]])
# tensor([[0.1645]])
# tensor([[0.1747]])
# tensor([[0.1852]])
# tensor([[0.1960]])
# tensor([[0.2071]])
# tensor([[0.2185]])
# tensor([[0.2302]])
# tensor([[0.2421]])
# tensor([[0.2544]])
# tensor([[0.2669]])
# tensor([[0.2797]])
# tensor([[0.2928]])
# tensor([[0.3062]])
# tensor([[0.3198]])
# tensor([[0.3338]])
# tensor([[0.3480]])
# tensor([[0.3625]])
# tensor([[0.3772]])
# tensor([[0.3922]])
# tensor([[0.4072]])
# tensor([[0.4225]])
# tensor([[0.4380]])
# tensor([[0.4537]])
# tensor([[0.4697]])
# tensor([[0.4859]])
# tensor([[0.5024]])
# tensor([[0.5191]])
# tensor([[0.5361]])
# tensor([[0.5533]])
# tensor([[0.5707]])
# tensor([[0.5884]])
# tensor([[0.6063]])
# tensor([[0.6244]])
# tensor([[0.6427]])
# tensor([[0.6613]])
# tensor([[0.6801]])
# tensor([[0.6991]])
# tensor([[0.7184]])
# tensor([[0.7378]])
# tensor([[0.7575]])
# tensor([[0.7774]])
# tensor([[0.7975]])
# tensor([[0.8178]])
# tensor([[0.8383]])
# tensor([[0.8590]])
# tensor([[0.8799]])
# tensor([[0.9009]])
# tensor([[0.9222]])
# tensor([[0.9437]])
# tensor([[0.9654]])
# tensor([[0.9872]])
# tensor([[1.0092]])
# tensor([[1.0314]])
# tensor([[1.0538]])
# tensor([[1.0763]])
# tensor([[1.0990]])
# tensor([[1.1219]])
# tensor([[1.1449]])
# tensor([[1.1681]])
# tensor([[1.1915]])
# tensor([[1.2150]])
# tensor([[1.2386]])
# tensor([[1.2624]])
# tensor([[1.2863]])
# tensor([[1.3104]])
# tensor([[1.3346]])
# tensor([[1.3589]])
# tensor([[1.3834]])
# tensor([[1.4079]])
# tensor([[1.4321]])
# tensor([[1.4564]])
# tensor([[1.4808]])
# tensor([[1.5053]])
# tensor([[1.5299]])
# tensor([[1.5545]])
# tensor([[1.5793]])
# tensor([[1.6041]])
# tensor([[1.6290]])
# tensor([[1.6540]])
# tensor([[1.6791]])
# tensor([[1.7042]])
# tensor([[1.7293]])
# tensor([[1.7546]])
# tensor([[1.7798]])
# tensor([[1.8052]])
# tensor([[1.8305]])
# tensor([[1.8559]])
# tensor([[1.8813]])
# tensor([[1.9068]])
# tensor([[1.9323]])
# tensor([[1.9578]])
# tensor([[1.9833]])
# tensor([[2.0088]])
# tensor([[2.0343]])
# tensor([[2.0598]])
# tensor([[2.0853]])
# tensor([[2.1107]])
# tensor([[2.1362]])
# tensor([[2.1616]])
# tensor([[2.1870]])
# tensor([[2.2124]])
# tensor([[2.2377]])
# tensor([[2.2630]])
# tensor([[2.2882]])
# tensor([[2.3134]])
# tensor([[2.3385]])
# tensor([[2.3636]])
# tensor([[2.3885]])
# tensor([[2.4134]])
# tensor([[2.4382]])
# tensor([[2.4629]])
# tensor([[2.4876]])
# tensor([[2.5121]])
# tensor([[2.5365]])
# tensor([[2.5608]])
# tensor([[2.5850]])
# tensor([[2.6091]])
# tensor([[2.6331]])
# tensor([[2.6569]])
# Epoch 200 || learning rate 9.22e-04  || Error  Train 3.04e+00 || Error Test  4.51e+00
# Global loss 2.70e+00 || loss ode 2.66e+00 || loss IC 4.16e-02
#
# tensor([[2.6801]])
# tensor([[2.7032]])
# tensor([[2.7262]])
# tensor([[2.7490]])
# tensor([[2.7716]])
# tensor([[2.7941]])
# tensor([[2.8165]])
# tensor([[2.8386]])
# tensor([[2.8607]])
# tensor([[2.8825]])
# tensor([[2.9042]])
# tensor([[2.9257]])
# tensor([[2.9470]])
# tensor([[2.9682]])
# tensor([[2.9891]])
# tensor([[3.0099]])
# tensor([[3.0305]])
# tensor([[3.0509]])
# tensor([[3.0711]])
# tensor([[3.0911]])
# tensor([[3.1109]])
# tensor([[3.1304]])
# tensor([[3.1498]])
# tensor([[3.1690]])
# tensor([[3.1880]])
# tensor([[3.2067]])
# tensor([[3.2252]])
# tensor([[3.2436]])
# tensor([[3.2617]])
# tensor([[3.2795]])
# tensor([[3.2972]])
# tensor([[3.3146]])
# tensor([[3.3318]])
# tensor([[3.3488]])
# tensor([[3.3656]])
# tensor([[3.3821]])
# tensor([[3.3984]])
# tensor([[3.4145]])
# tensor([[3.4304]])
# tensor([[3.4460]])
# tensor([[3.4614]])
# tensor([[3.4765]])
# tensor([[3.4914]])
# tensor([[3.5061]])
# tensor([[3.5206]])
# tensor([[3.5349]])
# tensor([[3.5489]])
# tensor([[3.5626]])
# tensor([[3.5762]])
# tensor([[3.5895]])
# tensor([[3.6024]])
# tensor([[3.6150]])
# tensor([[3.6274]])
# tensor([[3.6395]])
# tensor([[3.6515]])
# tensor([[3.6633]])
# tensor([[3.6748]])
# tensor([[3.6861]])
# tensor([[3.6972]])
# tensor([[3.7081]])
# tensor([[3.7188]])
# tensor([[3.7293]])
# tensor([[3.7396]])
# tensor([[3.7497]])
# tensor([[3.7596]])
# tensor([[3.7692]])
# tensor([[3.7787]])
# tensor([[3.7880]])
# tensor([[3.7972]])
# tensor([[3.8061]])
# tensor([[3.8148]])
# tensor([[3.8234]])
# tensor([[3.8317]])
# tensor([[3.8399]])
# tensor([[3.8479]])
# tensor([[3.8558]])
# tensor([[3.8634]])
# tensor([[3.8709]])
# tensor([[3.8783]])
# tensor([[3.8854]])
# tensor([[3.8924]])
# tensor([[3.8993]])
# tensor([[3.9059]])
# tensor([[3.9125]])
# tensor([[3.9188]])
# tensor([[3.9251]])
# tensor([[3.9311]])
# tensor([[3.9370]])
# tensor([[3.9428]])
# tensor([[3.9485]])
# tensor([[3.9540]])
# tensor([[3.9593]])
# tensor([[3.9646]])
# tensor([[3.9697]])
# tensor([[3.9746]])
# tensor([[3.9795]])
# tensor([[3.9842]])
# tensor([[3.9888]])
# tensor([[3.9933]])
# tensor([[3.9976]])
# tensor([[4.0018]])
# tensor([[4.0058]])
# tensor([[4.0098]])
# tensor([[4.0136]])
# tensor([[4.0173]])
# tensor([[4.0210]])
# tensor([[4.0245]])
# tensor([[4.0280]])
# tensor([[4.0313]])
# tensor([[4.0345]])
# tensor([[4.0377]])
# tensor([[4.0408]])
# tensor([[4.0438]])
# tensor([[4.0467]])
# tensor([[4.0495]])
# tensor([[4.0522]])
# tensor([[4.0549]])
# tensor([[4.0575]])
# tensor([[4.0600]])
# tensor([[4.0624]])
# tensor([[4.0648]])
# tensor([[4.0671]])
# tensor([[4.0693]])
# tensor([[4.0715]])
# tensor([[4.0736]])
# tensor([[4.0756]])
# tensor([[4.0776]])
# tensor([[4.0795]])
# tensor([[4.0814]])
# tensor([[4.0832]])
# tensor([[4.0850]])
# tensor([[4.0867]])
# tensor([[4.0883]])
# tensor([[4.0899]])
# tensor([[4.0914]])
# tensor([[4.0929]])
# tensor([[4.0944]])
# tensor([[4.0958]])
# tensor([[4.0972]])
# tensor([[4.0985]])
# tensor([[4.0998]])
# tensor([[4.1010]])
# tensor([[4.1022]])
# tensor([[4.1033]])
# tensor([[4.1045]])
# tensor([[4.1055]])
# tensor([[4.1066]])
# tensor([[4.1076]])
# tensor([[4.1086]])
# tensor([[4.1095]])
# tensor([[4.1104]])
# tensor([[4.1113]])
# tensor([[4.1121]])
# tensor([[4.1129]])
# tensor([[4.1137]])
# tensor([[4.1145]])
# tensor([[4.1152]])
# tensor([[4.1159]])
# tensor([[4.1166]])
# tensor([[4.1173]])
# tensor([[4.1179]])
# tensor([[4.1185]])
# tensor([[4.1191]])
# tensor([[4.1197]])
# tensor([[4.1202]])
# tensor([[4.1208]])
# tensor([[4.1213]])
# tensor([[4.1218]])
# tensor([[4.1223]])
# tensor([[4.1227]])
# tensor([[4.1232]])
# tensor([[4.1236]])
# tensor([[4.1240]])
# tensor([[4.1244]])
# tensor([[4.1248]])
# tensor([[4.1252]])
# tensor([[4.1256]])
# tensor([[4.1259]])
# tensor([[4.1262]])
# tensor([[4.1266]])
# tensor([[4.1269]])
# tensor([[4.1272]])
# tensor([[4.1275]])
# tensor([[4.1277]])
# tensor([[4.1280]])
# tensor([[4.1283]])
# tensor([[4.1285]])
# tensor([[4.1288]])
# tensor([[4.1290]])
# tensor([[4.1292]])
# tensor([[4.1294]])
# tensor([[4.1296]])
# tensor([[4.1298]])
# tensor([[4.1300]])
# tensor([[4.1302]])
# tensor([[4.1304]])
# tensor([[4.1305]])
# tensor([[4.1307]])
# tensor([[4.1309]])
# tensor([[4.1310]])
# Epoch 400 || learning rate 8.51e-04  || Error  Train 4.30e+00 || Error Test  6.26e+00
# Global loss 4.13e+00 || loss ode 4.13e+00 || loss IC 1.77e-07
#
# tensor([[4.1311]])
# tensor([[4.1313]])
# tensor([[4.1314]])
# tensor([[4.1315]])
# tensor([[4.1317]])
# tensor([[4.1318]])
# tensor([[4.1319]])
# tensor([[4.1320]])
# tensor([[4.1321]])
# tensor([[4.1322]])
# tensor([[4.1323]])
# tensor([[4.1324]])
# tensor([[4.1325]])
# tensor([[4.1325]])
# tensor([[4.1326]])
# tensor([[4.1327]])
# tensor([[4.1328]])
# tensor([[4.1328]])
# tensor([[4.1329]])
# tensor([[4.1330]])
# tensor([[4.1330]])
# tensor([[4.1331]])
# tensor([[4.1332]])
# tensor([[4.1332]])
# tensor([[4.1333]])
# tensor([[4.1333]])
# tensor([[4.1334]])
# tensor([[4.1334]])
# tensor([[4.1334]])
# tensor([[4.1335]])
# tensor([[4.1335]])
# tensor([[4.1336]])
# tensor([[4.1336]])
# tensor([[4.1336]])
# tensor([[4.1337]])
# tensor([[4.1337]])
# tensor([[4.1337]])
# tensor([[4.1338]])
# tensor([[4.1338]])
# tensor([[4.1338]])
# tensor([[4.1339]])
# tensor([[4.1339]])
# tensor([[4.1339]])
# tensor([[4.1339]])
# tensor([[4.1339]])
# tensor([[4.1340]])
# tensor([[4.1340]])
# tensor([[4.1340]])
# tensor([[4.1340]])
# tensor([[4.1340]])
# tensor([[4.1341]])
# tensor([[4.1341]])
# tensor([[4.1341]])
# tensor([[4.1341]])
# tensor([[4.1341]])
# tensor([[4.1341]])
# tensor([[4.1341]])
# tensor([[4.1341]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1342]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1343]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# Epoch 600 || learning rate 7.85e-04  || Error  Train 4.30e+00 || Error Test  6.27e+00
# Global loss 4.13e+00 || loss ode 4.13e+00 || loss IC 1.38e-16
#
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# Epoch 800 || learning rate 7.24e-04  || Error  Train 4.30e+00 || Error Test  6.27e+00
# Global loss 4.13e+00 || loss ode 4.13e+00 || loss IC 1.29e-26
#
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# Epoch 1000 || learning rate 6.68e-04  || Error  Train 4.30e+00 || Error Test  6.27e+00
# Global loss 4.13e+00 || loss ode 4.13e+00 || loss IC 4.44e-31
#
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# Epoch 1200 || learning rate 6.16e-04  || Error  Train 4.30e+00 || Error Test  6.27e+00
# Global loss 4.13e+00 || loss ode 4.13e+00 || loss IC 1.97e-31
#
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# Epoch 1400 || learning rate 5.68e-04  || Error  Train 4.30e+00 || Error Test  6.27e+00
# Global loss 4.13e+00 || loss ode 4.13e+00 || loss IC 4.93e-32
#
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# Epoch 1600 || learning rate 5.24e-04  || Error  Train 4.30e+00 || Error Test  6.27e+00
# Global loss 4.13e+00 || loss ode 4.13e+00 || loss IC 4.93e-32
#
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# Epoch 1800 || learning rate 4.83e-04  || Error  Train 4.30e+00 || Error Test  6.27e+00
# Global loss 4.13e+00 || loss ode 4.13e+00 || loss IC 4.93e-32
#
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# tensor([[4.1344]])
# Epoch 2000 || learning rate 4.46e-04  || Error  Train 4.30e+00 || Error Test  6.27e+00
# Global loss 4.13e+00 || loss ode 4.13e+00 || loss IC 4.93e-32

# %% [markdown]
# # Visualization of the results
# Value of the loss function throughout the optimization process

# %%
epochs = range(n_epochs+1)
#y_lims = [np.min(loss_values)*0.8,np.max(loss_values)*1.2]

fig, axs = plt.subplots(1,2,figsize = (15,7), num =4)
axs[0].semilogy(epochs,loss_values[:,0])
axs[0].set_xlabel('Numeber of Epochs')
#axs[0].set_ylim(y_lims)
axs[0].grid('on')
axs[0].set_title('Global loss')

axs[1].semilogy(epochs,loss_values[:,1],label = 'ODE')
axs[1].semilogy(epochs,loss_values[:,2],label = 'IC' )
axs[1].set_xlabel('Numeber of Epochs')
#axs[1].set_ylim(y_lims)
axs[1].legend()
axs[1].grid('on')
axs[1].set_title('Components loss')

plt.show()

# %% [markdown]
# Compare the exact solution with the PINN prediction and evaluate the pointwise error

# %%
t_test = convert(t_test)
y_NN_test = convert(y_NN_test)
t_sort_train = convert(t_sort_train)

# %%
fig, axs = plt.subplots(1,2,figsize = (15,7))
axs[0].plot(t_test,y_exact_test,label = 'Exact')
axs[0].plot(t_test,y_NN_test, label = 'Test prediction')
axs[0].set_xlabel('t')
axs[0].legend()
axs[0].set_title('Comparision')

axs[1].semilogy(t_test,np.abs(y_exact_test-y_NN_test))
axs[1].set_title('Point-wise error')
axs[1].set_xlabel('t')
axs[1].set_ylabel('|y - $y_{NN}$|')
plt.show()

# %% [markdown]
# $L^2$ Errors

# %%
epochs = range(n_epochs+1)
y_lims = [np.min(loss_values)*0.8,np.max(loss_values)*1.2]
plt.figure(4)
plt.semilogy(epochs,loss_values[:,0],label = 'values of the loss')
plt.semilogy(epochs[0:-1:STEP-1],err[:,0],'-x', label = '$L^2$ Training error')
plt.semilogy(epochs[0:-1:STEP-1],err[:,1],'-x', label = '$L^2$ Test error')

plt.xlabel('Number of epochs')
plt.grid('on')
plt.legend()
plt.show()

# %% [markdown]
# Animation of the solution and of the pointwise error during training

# %%
# %matplotlib widget
# fig, axs = plt.subplots(1,2, figsize = (15,7),num = 3)

# def updata_data(frame):
#     axs[0].clear()
#     axs[0].plot(t_sort_train,y_animate[frame,:],'b--',label = r'$y_{\Theta}$')
#     axs[0].plot(t_sort_train,y_exact_train_sort,'r', label = 'Exact')
#     axs[0].set_ylim([0,1.1])
#     axs[0].set_xlim([0,1])
#     axs[0].set_xlabel('t')

#     axs[0].grid('on')
#     axs[0].legend()

#     axs[1].clear()
#     axs[1].semilogy(t_sort_train,err_animate[frame,:])
#     axs[1].grid('on')
#     axs[1].set_ylim([np.min(err_animate)*0.9,np.max(err_animate)*1.1])
#     axs[1].set_xlabel('t')
#     axs[1].set_title(r'$|y - y_{\Theta}|$')
#     plt.suptitle(f'Epoch {frame*STEP} || error {err[frame,0]:.2e}')
#     return axs[0]

# animation = FuncAnimation(fig,func = updata_data,frames=len(y_animate),interval = 500,)
# plt.show()
# #for google colab
# #from IPython.display import HTML
# #video = HTML(anim.to_html5_video())
# #display(video)
# #plt.close()
